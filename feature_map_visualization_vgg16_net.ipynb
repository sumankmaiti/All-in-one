# %% [markdown]
# <a href="https://colab.research.google.com/github/sumankmaiti/All-in-one/blob/main/feature_map_visualization_vgg16_net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# visualize feature maps output from each block in the vgg model
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import Model
from matplotlib import pyplot as plt
from numpy import expand_dims

# %%
# load the model
model = VGG16()
# redefine model to output right after the first hidden layer
ixs = [2, 5, 9, 13, 17]
outputs = [model.layers[i].output for i in ixs]
print(outputs)
# Out:
# [<KerasTensor: shape=(None, 224, 224, 64) dtype=float32 (created by layer 'block1_conv2')>, <KerasTensor: shape=(None, 112, 112, 128) dtype=float32 (created by layer 'block2_conv2')>, <KerasTensor: shape=(None, 56, 56, 256) dtype=float32 (created by layer 'block3_conv3')>, <KerasTensor: shape=(None, 28, 28, 512) dtype=float32 (created by layer 'block4_conv3')>, <KerasTensor: shape=(None, 14, 14, 512) dtype=float32 (created by layer 'block5_conv3')>]

# %%
model = Model(inputs=model.inputs, outputs=outputs)

# %%
# load the image with the required shape
img = load_img('/content/drive/MyDrive/dataset_and_generated_graph/same_resolution/test_data/878e20721e454c8e6c72b7b3064afb5b.jpg', target_size=(224, 224))
# convert the image to an array
img = img_to_array(img)
img.shape
# Out:
# (224, 224, 3)

# %%
# expand dimensions so that it represents a single 'sample'
img = expand_dims(img, axis=0)
print(img.shape)
# Out:
# (1, 224, 224, 3)

# %%
# prepare the image (e.g. scale pixel values for the vgg)
img = preprocess_input(img)

# %%
# get feature map for first hidden layer
feature_maps = model.predict(img)
print(img.shape)
# Out:
# (1, 224, 224, 3)

# %%
f0 = feature_maps[0]
f0.shape
# plot the output from each block
row = 1
column = 8
fig = plt.figure(figsize=(28, 28))
for i in range(1, row*column + 1):
  img = f0[0, :, :, i-1]
  fig.add_subplot(rows, column, i)
  plt.imshow(img, cmap= "gray")
plt.show()

# %%
f1 = feature_maps[1]
f1.shape
# plot the output from each block
row = 1
column = 8
fig = plt.figure(figsize=(28, 28))
for i in range(1, row*column + 1):
  img = f1[0, :, :, i-1]
  fig.add_subplot(rows, column, i)
  plt.imshow(img, cmap= "gray")
plt.show()

# %%
f2 = feature_maps[2]
f2.shape
# plot the output from each block
row = 1
column = 8
fig = plt.figure(figsize=(28, 28))
for i in range(1, row*column + 1):
  img = f2[0, :, :, i-1]
  fig.add_subplot(rows, column, i)
  plt.imshow(img, cmap= "gray")
plt.show()

# %%
f3 = feature_maps[3]
f3.shape
row = 2
column = 8
fig = plt.figure(figsize=(28, 28))
for i in range(1, row*column + 1):
  img = f3[0, :, :, i-1]
  fig.add_subplot(rows, column, i)
  plt.imshow(img, cmap= "gray")
plt.show()

# %%
f4 = feature_maps[4]
f4.shape
row = 2
column = 8
fig = plt.figure(figsize=(28, 28))
for i in range(1, row*column + 1):
  img = f4[0, :, :, i-1]
  fig.add_subplot(rows, column, i)
  plt.imshow(img, cmap= "gray")
plt.show()
