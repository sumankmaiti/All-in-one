# %% [markdown]
# <a href="https://colab.research.google.com/github/sumankmaiti/All-in-one/blob/main/Autoencoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Simple Autoencoder

# %%
import keras
from keras import layers

# This is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# This is our input image
input_img = keras.Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = layers.Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = layers.Dense(784, activation='sigmoid')(encoded)

# This model maps an input to its reconstruction
autoencoder = keras.Model(input_img, decoded)

# %%
# This model maps an input to its encoded representation
encoder = keras.Model(input_img, encoded)

# %%
# This is our encoded (32-dimensional) input
encoded_input = keras.Input(shape=(encoding_dim,))
# Retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# Create the decoder model
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

# %%
# regularizer
from keras import regularizers

encoding_dim = 32

input_img = keras.Input(shape=(784,))
# Add a Dense layer with a L1 activity regularizer
encoded = layers.Dense(encoding_dim, activation='relu',
                activity_regularizer=regularizers.l1(10e-5))(input_img)
decoded = layers.Dense(784, activation='sigmoid')(encoded)

autoencoder = keras.Model(input_img, decoded)

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
# dataset
from keras.datasets import mnist
import numpy as np
(x_train, _), (x_test, _) = mnist.load_data()

# %%
# normalization
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
autoencoder.fit(x_train, x_train,epochs=50, batch_size=256, shuffle=True, validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 3s 9ms/step - loss: 0.2830 - val_loss: 0.1937
# Epoch 2/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1761 - val_loss: 0.1602
# Epoch 3/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1524 - val_loss: 0.1429
# Epoch 4/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1383 - val_loss: 0.1315
# Epoch 5/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1288 - val_loss: 0.1237
# Epoch 6/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1219 - val_loss: 0.1178
# Epoch 7/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1168 - val_loss: 0.1135
# Epoch 8/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1130 - val_loss: 0.1103
# Epoch 9/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1105 - val_loss: 0.1082
# Epoch 10/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1087 - val_loss: 0.1068
# Epoch 11/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1075 - val_loss: 0.1057
# Epoch 12/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1066 - val_loss: 0.1049
# Epoch 13/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1058 - val_loss: 0.1043
# Epoch 14/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1052 - val_loss: 0.1038
# Epoch 15/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1047 - val_loss: 0.1033
# Epoch 16/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1043 - val_loss: 0.1028
# Epoch 17/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1039 - val_loss: 0.1024
# Epoch 18/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1035 - val_loss: 0.1021
# Epoch 19/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1032 - val_loss: 0.1019
# Epoch 20/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1029 - val_loss: 0.1015
# Epoch 21/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1026 - val_loss: 0.1014
# Epoch 22/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1023 - val_loss: 0.1010
# Epoch 23/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1021 - val_loss: 0.1008
# Epoch 24/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1019 - val_loss: 0.1006
# Epoch 25/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1017 - val_loss: 0.1004
# Epoch 26/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1015 - val_loss: 0.1002
# Epoch 27/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1013 - val_loss: 0.1000
# Epoch 28/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1011 - val_loss: 0.0999
# Epoch 29/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1010 - val_loss: 0.0997
# Epoch 30/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1008 - val_loss: 0.0996
# Epoch 31/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1007 - val_loss: 0.0994
# Epoch 32/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1005 - val_loss: 0.0993
# Epoch 33/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1004 - val_loss: 0.0991
# Epoch 34/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1003 - val_loss: 0.0990
# Epoch 35/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1001 - val_loss: 0.0989
# Epoch 36/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1000 - val_loss: 0.0989
# Epoch 37/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0999 - val_loss: 0.0987
# Epoch 38/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0998 - val_loss: 0.0986
# Epoch 39/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0997 - val_loss: 0.0985
# Epoch 40/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0996 - val_loss: 0.0984
# Epoch 41/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0995 - val_loss: 0.0984
# Epoch 42/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0994 - val_loss: 0.0983
# Epoch 43/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0993 - val_loss: 0.0982
# Epoch 44/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0993 - val_loss: 0.0981
# Epoch 45/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0992 - val_loss: 0.0980
# Epoch 46/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0991 - val_loss: 0.0979
# Epoch 47/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0990 - val_loss: 0.0979
# Epoch 48/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0989 - val_loss: 0.0978
# Epoch 49/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0989 - val_loss: 0.0977
# Epoch 50/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0988 - val_loss: 0.0977

# %%
# Encode and decode some digits
# Note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
# Use Matplotlib (don't ask)
import matplotlib.pyplot as plt

n = 10  # How many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# Deep Autoencoder

# %%
input_img = keras.Input(shape=(784,))
encoded = layers.Dense(128, activation='relu')(input_img)
encoded = layers.Dense(64, activation='relu')(encoded)
encoded = layers.Dense(32, activation='relu')(encoded)

decoded = layers.Dense(64, activation='relu')(encoded)
decoded = layers.Dense(128, activation='relu')(decoded)
decoded = layers.Dense(784, activation='sigmoid')(decoded)

# %%
autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 235/235 [==============================] - 4s 14ms/step - loss: 0.2420 - val_loss: 0.1659
# Epoch 2/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1473 - val_loss: 0.1333
# Epoch 3/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1292 - val_loss: 0.1235
# Epoch 4/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1209 - val_loss: 0.1163
# Epoch 5/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1152 - val_loss: 0.1120
# Epoch 6/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1112 - val_loss: 0.1081
# Epoch 7/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1081 - val_loss: 0.1053
# Epoch 8/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1056 - val_loss: 0.1037
# Epoch 9/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1035 - val_loss: 0.1013
# Epoch 10/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1018 - val_loss: 0.0998
# Epoch 11/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1003 - val_loss: 0.0985
# Epoch 12/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0990 - val_loss: 0.0971
# Epoch 13/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0978 - val_loss: 0.0961
# Epoch 14/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0967 - val_loss: 0.0954
# Epoch 15/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0957 - val_loss: 0.0945
# Epoch 16/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0948 - val_loss: 0.0938
# Epoch 17/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0942 - val_loss: 0.0929
# Epoch 18/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0935 - val_loss: 0.0923
# Epoch 19/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0930 - val_loss: 0.0920
# Epoch 20/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0924 - val_loss: 0.0922
# Epoch 21/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0919 - val_loss: 0.0910
# Epoch 22/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0914 - val_loss: 0.0903
# Epoch 23/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0909 - val_loss: 0.0898
# Epoch 24/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0905 - val_loss: 0.0899
# Epoch 25/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0900 - val_loss: 0.0893
# Epoch 26/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0896 - val_loss: 0.0885
# Epoch 27/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0892 - val_loss: 0.0887
# Epoch 28/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0888 - val_loss: 0.0880
# Epoch 29/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0885 - val_loss: 0.0879
# Epoch 30/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0882 - val_loss: 0.0877
# Epoch 31/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0879 - val_loss: 0.0877
# Epoch 32/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0877 - val_loss: 0.0872
# Epoch 33/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0874 - val_loss: 0.0868
# Epoch 34/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0872 - val_loss: 0.0865
# Epoch 35/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0869 - val_loss: 0.0862
# Epoch 36/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0868 - val_loss: 0.0861
# Epoch 37/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0865 - val_loss: 0.0857
# Epoch 38/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0863 - val_loss: 0.0856
# Epoch 39/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0861 - val_loss: 0.0856
# Epoch 40/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0859 - val_loss: 0.0853
# Epoch 41/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0858 - val_loss: 0.0852
# Epoch 42/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0856 - val_loss: 0.0851
# Epoch 43/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0855 - val_loss: 0.0849
# Epoch 44/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0854 - val_loss: 0.0847
# Epoch 45/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0852 - val_loss: 0.0850
# Epoch 46/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0851 - val_loss: 0.0848
# Epoch 47/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0850 - val_loss: 0.0846
# Epoch 48/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0849 - val_loss: 0.0844
# Epoch 49/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0848 - val_loss: 0.0844
# Epoch 50/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0846 - val_loss: 0.0842
# Epoch 51/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0846 - val_loss: 0.0842
# Epoch 52/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0845 - val_loss: 0.0844
# Epoch 53/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0844 - val_loss: 0.0842
# Epoch 54/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0843 - val_loss: 0.0839
# Epoch 55/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0842 - val_loss: 0.0837
# Epoch 56/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0841 - val_loss: 0.0836
# Epoch 57/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0841 - val_loss: 0.0840
# Epoch 58/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0840 - val_loss: 0.0835
# Epoch 59/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0839 - val_loss: 0.0839
# Epoch 60/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0839 - val_loss: 0.0835
# Epoch 61/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0838 - val_loss: 0.0834
# Epoch 62/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0837 - val_loss: 0.0836
# Epoch 63/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0837 - val_loss: 0.0835
# Epoch 64/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0837 - val_loss: 0.0832
# Epoch 65/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0836 - val_loss: 0.0833
# Epoch 66/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0835 - val_loss: 0.0832
# Epoch 67/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0834 - val_loss: 0.0830
# Epoch 68/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0834 - val_loss: 0.0832
# Epoch 69/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0833 - val_loss: 0.0833
# Epoch 70/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0833 - val_loss: 0.0829
# Epoch 71/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0832 - val_loss: 0.0832
# Epoch 72/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0832 - val_loss: 0.0831
# Epoch 73/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0831 - val_loss: 0.0829
# Epoch 74/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0831 - val_loss: 0.0830
# Epoch 75/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0831 - val_loss: 0.0827
# Epoch 76/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0830 - val_loss: 0.0832
# Epoch 77/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0830 - val_loss: 0.0825
# Epoch 78/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0829 - val_loss: 0.0828
# Epoch 79/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0829 - val_loss: 0.0826
# Epoch 80/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0828 - val_loss: 0.0825
# Epoch 81/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0828 - val_loss: 0.0825
# Epoch 82/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0828 - val_loss: 0.0828
# Epoch 83/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0827 - val_loss: 0.0825
# Epoch 84/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0827 - val_loss: 0.0826
# Epoch 85/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0827 - val_loss: 0.0823
# Epoch 86/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0826 - val_loss: 0.0825
# Epoch 87/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0826 - val_loss: 0.0823
# Epoch 88/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0826 - val_loss: 0.0823
# Epoch 89/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0825 - val_loss: 0.0824
# Epoch 90/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0825 - val_loss: 0.0823
# Epoch 91/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0825 - val_loss: 0.0823
# Epoch 92/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0824 - val_loss: 0.0822
# Epoch 93/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0824 - val_loss: 0.0823
# Epoch 94/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0824 - val_loss: 0.0820
# Epoch 95/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0824 - val_loss: 0.0824
# Epoch 96/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0823 - val_loss: 0.0822
# Epoch 97/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0823 - val_loss: 0.0824
# Epoch 98/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0822 - val_loss: 0.0821
# Epoch 99/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0822 - val_loss: 0.0821
# Epoch 100/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0822 - val_loss: 0.0822

# %%
# Use Matplotlib (don't ask)
import matplotlib.pyplot as plt

n = 10  # How many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# Convolutional autoencoder

# %%
import keras
from keras import layers

input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(16, (3, 3), activation='relu')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
from keras.datasets import mnist
import numpy as np

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# %%
tensorboard --logdir=/tmp/autoencoder

# %%
from keras.callbacks import TensorBoard

autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=[TensorBoard(log_dir='/tmp/autoencoder')])
# Out:
# Epoch 1/50
# 469/469 [==============================] - 65s 138ms/step - loss: 0.2061 - val_loss: 0.1435
# Epoch 2/50
# 469/469 [==============================] - 64s 137ms/step - loss: 0.1350 - val_loss: 0.1263
# Epoch 3/50
# 469/469 [==============================] - 65s 138ms/step - loss: 0.1230 - val_loss: 0.1176
# Epoch 4/50
# 469/469 [==============================] - 65s 139ms/step - loss: 0.1164 - val_loss: 0.1129
# Epoch 5/50
# 469/469 [==============================] - 65s 138ms/step - loss: 0.1122 - val_loss: 0.1090
# Epoch 6/50
# 469/469 [==============================] - 65s 138ms/step - loss: 0.1092 - val_loss: 0.1068
# Epoch 7/50
# 469/469 [==============================] - 65s 140ms/step - loss: 0.1069 - val_loss: 0.1052
# Epoch 8/50
# 469/469 [==============================] - 68s 144ms/step - loss: 0.1053 - val_loss: 0.1035
# Epoch 9/50
# 469/469 [==============================] - 65s 139ms/step - loss: 0.1040 - val_loss: 0.1023
# Epoch 10/50
# 469/469 [==============================] - 65s 139ms/step - loss: 0.1030 - val_loss: 0.1013
# Epoch 11/50
# 469/469 [==============================] - 65s 139ms/step - loss: 0.1021 - val_loss: 0.1013
# Epoch 12/50
# 469/469 [==============================] - 65s 139ms/step - loss: 0.1014 - val_loss: 0.1002
# Epoch 13/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.1008 - val_loss: 0.0994
# Epoch 14/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.1003 - val_loss: 0.0990
# Epoch 15/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.0997 - val_loss: 0.0985
# Epoch 16/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.0993 - val_loss: 0.0979
# Epoch 17/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.0989 - val_loss: 0.0978
# Epoch 18/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.0985 - val_loss: 0.0973
# Epoch 19/50
# 469/469 [==============================] - 65s 140ms/step - loss: 0.0982 - val_loss: 0.0970
# Epoch 20/50
# 469/469 [==============================] - 65s 140ms/step - loss: 0.0978 - val_loss: 0.0966
# Epoch 21/50
# 469/469 [==============================] - 65s 139ms/step - loss: 0.0976 - val_loss: 0.0964
# Epoch 22/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.0973 - val_loss: 0.0961
# Epoch 23/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.0970 - val_loss: 0.0958
# Epoch 24/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.0968 - val_loss: 0.0954
# Epoch 25/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.0966 - val_loss: 0.0953
# Epoch 26/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.0964 - val_loss: 0.0951
# Epoch 27/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.0962 - val_loss: 0.0952
# Epoch 28/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.0960 - val_loss: 0.0951
# Epoch 29/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.0958 - val_loss: 0.0948
# Epoch 30/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.0956 - val_loss: 0.0958
# Epoch 31/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.0955 - val_loss: 0.0946
# Epoch 32/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.0954 - val_loss: 0.0943
# Epoch 33/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.0952 - val_loss: 0.0943
# Epoch 34/50
# 469/469 [==============================] - 68s 145ms/step - loss: 0.0950 - val_loss: 0.0939
# Epoch 35/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.0949 - val_loss: 0.0939
# Epoch 36/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.0948 - val_loss: 0.0935
# Epoch 37/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.0947 - val_loss: 0.0939
# Epoch 38/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.0946 - val_loss: 0.0933
# Epoch 39/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.0944 - val_loss: 0.0932
# Epoch 40/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.0943 - val_loss: 0.0932
# Epoch 41/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.0942 - val_loss: 0.0934
# Epoch 42/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.0941 - val_loss: 0.0930
# Epoch 43/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.0941 - val_loss: 0.0930
# Epoch 44/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.0940 - val_loss: 0.0931
# Epoch 45/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.0939 - val_loss: 0.0927
# Epoch 46/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.0938 - val_loss: 0.0927
# Epoch 47/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.0937 - val_loss: 0.0924
# Epoch 48/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.0935 - val_loss: 0.0924
# Epoch 49/50
# 469/469 [==============================] - 66s 142ms/step - loss: 0.0935 - val_loss: 0.0924
# Epoch 50/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.0934 - val_loss: 0.0923

# %%
# outputs
decoded_imgs = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
# visualize the latents
encoder = keras.Model(input_img, encoded)
encoded_imgs = encoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 8))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(encoded_imgs[i].reshape((4, 4 * 8)).T)
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# Image denoising

# %%
from keras.datasets import mnist
import numpy as np

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

#apply noise
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape) 
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape) 

# clipping the values between 0 and 1
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
import matplotlib.pyplot as plt
n = 10
plt.figure(figsize=(20, 2))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
import keras
from keras import layers
input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# At this point the representation is (7, 7, 32)

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
from keras.callbacks import TensorBoard
autoencoder.fit(x_train_noisy, x_train,
                epochs=50,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test_noisy, x_test),
                callbacks=[TensorBoard(log_dir='/tmp/tb', histogram_freq=0, write_graph=False)])
# Out:
# Epoch 1/50
# 469/469 [==============================] - 146s 309ms/step - loss: 0.1645 - val_loss: 0.1174
# Epoch 2/50
# 469/469 [==============================] - 146s 312ms/step - loss: 0.1143 - val_loss: 0.1095
# Epoch 3/50
# 469/469 [==============================] - 146s 311ms/step - loss: 0.1086 - val_loss: 0.1056
# Epoch 4/50
# 469/469 [==============================] - 146s 312ms/step - loss: 0.1055 - val_loss: 0.1035
# Epoch 5/50
# 469/469 [==============================] - 145s 310ms/step - loss: 0.1034 - val_loss: 0.1013
# Epoch 6/50
# 469/469 [==============================] - 144s 307ms/step - loss: 0.1019 - val_loss: 0.1002
# Epoch 7/50
# 469/469 [==============================] - 144s 307ms/step - loss: 0.1007 - val_loss: 0.0996
# Epoch 8/50
# 469/469 [==============================] - 144s 307ms/step - loss: 0.0999 - val_loss: 0.0987
# Epoch 9/50
# 469/469 [==============================] - 144s 307ms/step - loss: 0.0992 - val_loss: 0.0981
# Epoch 10/50
# 469/469 [==============================] - 143s 305ms/step - loss: 0.0986 - val_loss: 0.0975
# Epoch 11/50
# 469/469 [==============================] - 143s 305ms/step - loss: 0.0981 - val_loss: 0.0969
# Epoch 12/50
# 469/469 [==============================] - 143s 304ms/step - loss: 0.0976 - val_loss: 0.0967
# Epoch 13/50
# 469/469 [==============================] - 143s 305ms/step - loss: 0.0972 - val_loss: 0.0963
# Epoch 14/50
# 469/469 [==============================] - 143s 304ms/step - loss: 0.0969 - val_loss: 0.0962
# Epoch 15/50
# 469/469 [==============================] - 143s 304ms/step - loss: 0.0966 - val_loss: 0.0958
# Epoch 16/50
# 469/469 [==============================] - 143s 304ms/step - loss: 0.0964 - val_loss: 0.0958
# Epoch 17/50
# 469/469 [==============================] - 143s 305ms/step - loss: 0.0961 - val_loss: 0.0957
# Epoch 18/50
# 469/469 [==============================] - 143s 306ms/step - loss: 0.0960 - val_loss: 0.0960
# Epoch 19/50
# 469/469 [==============================] - 143s 305ms/step - loss: 0.0958 - val_loss: 0.0952
# Epoch 20/50
# 469/469 [==============================] - 143s 306ms/step - loss: 0.0956 - val_loss: 0.0950
# Epoch 21/50
# 469/469 [==============================] - 144s 306ms/step - loss: 0.0954 - val_loss: 0.0952
# Epoch 22/50
# 469/469 [==============================] - 144s 307ms/step - loss: 0.0953 - val_loss: 0.0949
# Epoch 23/50
# 469/469 [==============================] - 144s 306ms/step - loss: 0.0952 - val_loss: 0.0948
# Epoch 24/50
# 469/469 [==============================] - 144s 306ms/step - loss: 0.0951 - val_loss: 0.0945
# Epoch 25/50
# 469/469 [==============================] - 143s 306ms/step - loss: 0.0950 - val_loss: 0.0952
# Epoch 26/50
# 469/469 [==============================] - 145s 308ms/step - loss: 0.0949 - val_loss: 0.0945
# Epoch 27/50
# 469/469 [==============================] - 144s 307ms/step - loss: 0.0948 - val_loss: 0.0944
# Epoch 28/50
# 469/469 [==============================] - 144s 307ms/step - loss: 0.0947 - val_loss: 0.0942
# Epoch 29/50
# 469/469 [==============================] - 144s 307ms/step - loss: 0.0946 - val_loss: 0.0941
# Epoch 30/50
# 469/469 [==============================] - 144s 307ms/step - loss: 0.0946 - val_loss: 0.0941
# Epoch 31/50
# 469/469 [==============================] - 144s 308ms/step - loss: 0.0945 - val_loss: 0.0940
# Epoch 32/50
# 469/469 [==============================] - 145s 308ms/step - loss: 0.0944 - val_loss: 0.0941
# Epoch 33/50
# 469/469 [==============================] - 145s 309ms/step - loss: 0.0944 - val_loss: 0.0940
# Epoch 34/50
# 469/469 [==============================] - 145s 309ms/step - loss: 0.0943 - val_loss: 0.0940
# Epoch 35/50
# 469/469 [==============================] - 145s 309ms/step - loss: 0.0943 - val_loss: 0.0943
# Epoch 36/50
# 469/469 [==============================] - 145s 310ms/step - loss: 0.0942 - val_loss: 0.0940
# Epoch 37/50
# 469/469 [==============================] - 146s 311ms/step - loss: 0.0941 - val_loss: 0.0939
# Epoch 38/50
# 469/469 [==============================] - 147s 313ms/step - loss: 0.0941 - val_loss: 0.0941
# Epoch 39/50
# 469/469 [==============================] - 146s 312ms/step - loss: 0.0941 - val_loss: 0.0938
# Epoch 40/50
# 469/469 [==============================] - 146s 310ms/step - loss: 0.0940 - val_loss: 0.0937
# Epoch 41/50
# 469/469 [==============================] - 145s 310ms/step - loss: 0.0940 - val_loss: 0.0939
# Epoch 42/50
# 469/469 [==============================] - 145s 309ms/step - loss: 0.0940 - val_loss: 0.0937
# Epoch 43/50
# 469/469 [==============================] - 144s 308ms/step - loss: 0.0939 - val_loss: 0.0938
# Epoch 44/50
# 469/469 [==============================] - 144s 308ms/step - loss: 0.0939 - val_loss: 0.0938
# Epoch 45/50
# 469/469 [==============================] - 146s 311ms/step - loss: 0.0939 - val_loss: 0.0936
# Epoch 46/50
# 469/469 [==============================] - 144s 308ms/step - loss: 0.0938 - val_loss: 0.0937
# Epoch 47/50
# 469/469 [==============================] - 145s 309ms/step - loss: 0.0938 - val_loss: 0.0937
# Epoch 48/50
# 469/469 [==============================] - 145s 308ms/step - loss: 0.0937 - val_loss: 0.0938
# Epoch 49/50
# 469/469 [==============================] - 146s 311ms/step - loss: 0.0938 - val_loss: 0.0937
# Epoch 50/50
# 469/469 [==============================] - 145s 310ms/step - loss: 0.0937 - val_loss: 0.0936

# %%
# outputs
decoded_imgs = autoencoder.predict(x_test_noisy)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# Variational autoencoder (VAE)

# %%
original_dim = 28 * 28
intermediate_dim = 64
latent_dim = 2

inputs = keras.Input(shape=(original_dim,))
h = layers.Dense(intermediate_dim, activation='relu')(inputs)
z_mean = layers.Dense(latent_dim)(h)
z_log_sigma = layers.Dense(latent_dim)(h)

# %%
from keras import backend as K

def sampling(args):
    z_mean, z_log_sigma = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim),
                              mean=0., stddev=0.1)
    return z_mean + K.exp(z_log_sigma) * epsilon

z = layers.Lambda(sampling)([z_mean, z_log_sigma])

# %%
# Create encoder
encoder = keras.Model(inputs, [z_mean, z_log_sigma, z], name='encoder')

# Create decoder
latent_inputs = keras.Input(shape=(latent_dim,), name='z_sampling')
x = layers.Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = layers.Dense(original_dim, activation='sigmoid')(x)
decoder = keras.Model(latent_inputs, outputs, name='decoder')

# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = keras.Model(inputs, outputs, name='vae_mlp')

# %%
reconstruction_loss = keras.losses.binary_crossentropy(inputs, outputs)
reconstruction_loss *= original_dim
kl_loss = 1 + z_log_sigma - K.square(z_mean) - K.exp(z_log_sigma)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

vae.fit(x_train, x_train,
        epochs=100,
        batch_size=32,
        validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 185.3672 - val_loss: 167.3961
# Epoch 2/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 164.8611 - val_loss: 163.3727
# Epoch 3/100
# 1875/1875 [==============================] - 7s 3ms/step - loss: 161.7086 - val_loss: 160.9863
# Epoch 4/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 159.6666 - val_loss: 159.0114
# Epoch 5/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 157.8583 - val_loss: 157.2432
# Epoch 6/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 156.2659 - val_loss: 155.9737
# Epoch 7/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 155.0135 - val_loss: 154.6731
# Epoch 8/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 154.0725 - val_loss: 154.0223
# Epoch 9/100
# 1875/1875 [==============================] - 7s 3ms/step - loss: 153.4044 - val_loss: 153.4539
# Epoch 10/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 152.8116 - val_loss: 152.8044
# Epoch 11/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 152.3173 - val_loss: 152.6978
# Epoch 12/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 151.8794 - val_loss: 152.2987
# Epoch 13/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 151.4766 - val_loss: 151.7357
# Epoch 14/100
# 1875/1875 [==============================] - 7s 3ms/step - loss: 151.1467 - val_loss: 151.4851
# Epoch 15/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 150.7880 - val_loss: 151.2260
# Epoch 16/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 150.4976 - val_loss: 151.0366
# Epoch 17/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 150.2300 - val_loss: 150.8235
# Epoch 18/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 149.9846 - val_loss: 150.6278
# Epoch 19/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 149.7472 - val_loss: 150.3741
# Epoch 20/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 149.5250 - val_loss: 150.1639
# Epoch 21/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 149.3209 - val_loss: 149.9288
# Epoch 22/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 149.1260 - val_loss: 149.8132
# Epoch 23/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 148.9680 - val_loss: 149.8626
# Epoch 24/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 148.7807 - val_loss: 149.7079
# Epoch 25/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 148.6124 - val_loss: 149.4229
# Epoch 26/100
# 1875/1875 [==============================] - 7s 3ms/step - loss: 148.4850 - val_loss: 149.3937
# Epoch 27/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 148.3368 - val_loss: 149.3770
# Epoch 28/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 148.2121 - val_loss: 149.3588
# Epoch 29/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 148.0700 - val_loss: 149.0219
# Epoch 30/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 147.9469 - val_loss: 148.9743
# Epoch 31/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 147.8121 - val_loss: 148.8515
# Epoch 32/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 147.7090 - val_loss: 148.8030
# Epoch 33/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 147.5758 - val_loss: 148.6127
# Epoch 34/100
# 1875/1875 [==============================] - 7s 3ms/step - loss: 147.4613 - val_loss: 148.7571
# Epoch 35/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 147.3419 - val_loss: 148.4077
# Epoch 36/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 147.2611 - val_loss: 148.6397
# Epoch 37/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 147.1414 - val_loss: 148.4289
# Epoch 38/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 147.0473 - val_loss: 148.5215
# Epoch 39/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 146.9638 - val_loss: 148.3698
# Epoch 40/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 146.8755 - val_loss: 148.3120
# Epoch 41/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 146.7862 - val_loss: 148.1487
# Epoch 42/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 146.6900 - val_loss: 148.2712
# Epoch 43/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 146.6018 - val_loss: 148.1354
# Epoch 44/100
# 1875/1875 [==============================] - 7s 3ms/step - loss: 146.5191 - val_loss: 148.2773
# Epoch 45/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 146.4367 - val_loss: 147.9079
# Epoch 46/100
# 1875/1875 [==============================] - 7s 3ms/step - loss: 146.4168 - val_loss: 147.8322
# Epoch 47/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 146.2934 - val_loss: 147.6397
# Epoch 48/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 146.2259 - val_loss: 147.7239
# Epoch 49/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 146.1437 - val_loss: 147.7737
# Epoch 50/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 146.0875 - val_loss: 148.1145
# Epoch 51/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 146.0027 - val_loss: 147.7309
# Epoch 52/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 145.9373 - val_loss: 147.6204
# Epoch 53/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 145.8607 - val_loss: 147.4731
# Epoch 54/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 145.8091 - val_loss: 147.6890
# Epoch 55/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 145.7447 - val_loss: 147.3668
# Epoch 56/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 145.6790 - val_loss: 147.2983
# Epoch 57/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 145.5856 - val_loss: 147.4490
# Epoch 58/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 145.5573 - val_loss: 147.4433
# Epoch 59/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 145.5053 - val_loss: 147.3424
# Epoch 60/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 145.4168 - val_loss: 147.0807
# Epoch 61/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 145.3539 - val_loss: 147.0013
# Epoch 62/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 145.3113 - val_loss: 147.2409
# Epoch 63/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 145.2343 - val_loss: 146.9349
# Epoch 64/100
# 1875/1875 [==============================] - 7s 3ms/step - loss: 145.2213 - val_loss: 147.1937
# Epoch 65/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 145.1007 - val_loss: 146.8201
# Epoch 66/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 145.0717 - val_loss: 147.2157
# Epoch 67/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 145.0300 - val_loss: 146.9492
# Epoch 68/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.9859 - val_loss: 147.0853
# Epoch 69/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.9304 - val_loss: 147.0821
# Epoch 70/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.8476 - val_loss: 146.9440
# Epoch 71/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.8436 - val_loss: 146.7765
# Epoch 72/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.7668 - val_loss: 146.8399
# Epoch 73/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.7146 - val_loss: 146.9482
# Epoch 74/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.7052 - val_loss: 146.8546
# Epoch 75/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.6145 - val_loss: 147.0150
# Epoch 76/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.5844 - val_loss: 147.1062
# Epoch 77/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.5195 - val_loss: 146.8016
# Epoch 78/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.4933 - val_loss: 146.8950
# Epoch 79/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.4360 - val_loss: 146.5930
# Epoch 80/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.4225 - val_loss: 146.5532
# Epoch 81/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.3634 - val_loss: 146.5777
# Epoch 82/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.3087 - val_loss: 146.4003
# Epoch 83/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.2772 - val_loss: 146.7994
# Epoch 84/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.2099 - val_loss: 146.3210
# Epoch 85/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.1909 - val_loss: 146.5064
# Epoch 86/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.1442 - val_loss: 146.6909
# Epoch 87/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.1093 - val_loss: 146.5968
# Epoch 88/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.0465 - val_loss: 146.3392
# Epoch 89/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.0143 - val_loss: 146.6311
# Epoch 90/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 144.0059 - val_loss: 146.4146
# Epoch 91/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 143.9347 - val_loss: 146.6339
# Epoch 92/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 143.9288 - val_loss: 146.2260
# Epoch 93/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 143.8798 - val_loss: 146.3105
# Epoch 94/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 143.8469 - val_loss: 146.4049
# Epoch 95/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 143.8207 - val_loss: 146.4588
# Epoch 96/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 143.8164 - val_loss: 146.4816
# Epoch 97/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 143.7519 - val_loss: 146.0863
# Epoch 98/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 143.7528 - val_loss: 146.3033
# Epoch 99/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 143.6704 - val_loss: 146.0758
# Epoch 100/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 143.6559 - val_loss: 146.1912

# %%
x_test_encoded = vae.predict(x_test)
plt.figure(figsize=(6, 6))
plt.scatter(x_test_encoded[:, 0], x_test_encoded[:, 1], c=y_test)
plt.colorbar()
plt.show()

# %%
# Display a 2D manifold of the digits
n = 15  # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
# We will sample n points within [-15, 15] standard deviations
grid_x = np.linspace(-15, 15, n)
grid_y = np.linspace(-15, 15, n)

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure)
plt.show()
