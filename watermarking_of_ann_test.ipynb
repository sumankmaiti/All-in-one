# %% [markdown]
# <a href="https://colab.research.google.com/github/sumankmaiti/All-in-one/blob/main/watermarking_of_ann_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from math import exp
from random import seed
from random import random
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %% [markdown]
# model build

# %%
# Initialize a network. Parameters are initialized using gaussian distribution
def initialize_network(inputs, outputs):
  network = list()

  hidden_layer_1 = [{'weights':[np.random.normal(0.0, .01) for i in range(inputs + 1)]} for i in range(7)]
  network.append(hidden_layer_1)

  hidden_layer_2 = [{'weights':[np.random.normal(0.0, .01) for i in range(7 + 1)]} for i in range(5)]
  network.append(hidden_layer_2)

  hidden_layer_3 = [{'weights':[np.random.normal(0.0, .01) for i in range(5 + 1)]} for i in range(3)]
  network.append(hidden_layer_3)

  output_layer = [{'weights':[np.random.normal(0.0, .01) for i in range(3 + 1)]} for i in range(outputs)]
  network.append(output_layer)
  return network

# %%
# Calculate neuron activation for an input
def weighted_sum(weights, inputs):
	bias = weights[-1] # last value of the 'weights' is used for bias
	for i in range(len(weights)-1): # loop till 2nd last element
		bias += weights[i] * inputs[i] # weighted sum
	return bias

# %%
# Transfer neuron activation
def sigmoid(activation):
	return 1.0 / (1.0 + exp(-activation))

# %%
# Forward propagate input to a network output
def forward_propagate(network, row):
	inputs = row
	for layer in network:
		new_inputs = []   # store the output of the neurons for a layer
		for neuron in layer: 
			activation = weighted_sum(neuron['weights'], inputs) # weighted sum
			neuron['output'] = sigmoid(activation)  # sigmoid activation 
			new_inputs.append(neuron['output']) # output of the neurons in a layer
		inputs = new_inputs  # make the output of a layer as input for the next layer
	return inputs # final output from output layer

# %%
# Calculate the derivative of a neuron output
def derivative(output):
	return output * (1.0 - output)

# %%
# Backpropagate error and store in neurons
def backward_propagate_error(network, expected):
	for i in reversed(range(len(network))):
		layer = network[i] # last to first
		errors = list() 
		if i != len(network)-1: # from 2nd last to first layer
			for j in range(len(layer)):
				error = 0.0
				for neuron in network[i + 1]: # 
					error += (neuron['weights'][j] * neuron['delta']) # total error for a neuron w.r.t connected neurons from back
				errors.append(error)
		else:   # 1st execute here to calculate loss (expected - predected) 
			for j in range(len(layer)): # last layer
				neuron = layer[j]
				errors.append(expected[j] - neuron['output']) # loss of output neurons
		for j in range(len(layer)):  # calculate gradient/ derivative(small portion from error w.r.t output of that neuron)
			neuron = layer[j]
			neuron['delta'] = errors[j] * derivative(neuron['output']) # store the derivative

# %%
# Update network weights with error
def update_weights(network, row, l_rate, W):
  for i in range(len(network)):
    inputs = row[:-1]
    if i != 0:
      inputs = [neuron['output'] for neuron in network[i - 1]]  # from 2nd layer output of 1st= input of 2nd
    for neuron in range(len(network[i])):  # neuron in a layer
      # print(network[i][neuron])   
      for j in range(len(inputs)):
        try:
          layer_number = W[i][0]
        except:
          layer_number = -10
        if neuron == layer_number:
          try:
            weight_number = W[i][1]
          except:
            weight_number = -10
          if j == weight_number:
            # network[i][neuron]['weights'][j] += 0 * l_rate * network[i][neuron]['delta'] * inputs[j]
            network[i][neuron]['weights'][j] += 0 * l_rate * network[i][neuron]['delta']
            # print(network[i][neuron]['weights'][j])  
          else:
            # network[i][neuron]['weights'][j] += l_rate * network[i][neuron]['delta'] * inputs[j] 
            network[i][neuron]['weights'][j] += l_rate * network[i][neuron]['delta'] 
        else:
          # print(network[i][neuron])
          # network[i][neuron]['weights'][j] += l_rate * network[i][neuron]['delta'] * inputs[j]
          network[i][neuron]['weights'][j] += l_rate * network[i][neuron]['delta'] 
      # for j in range(len(inputs)):
      #   print(network[i][neuron]['weights'][j])
      #   neuron['weights'][j] += l_rate * neuron['delta'] * inputs[j]
      network[i][neuron]['weights'][-1] += l_rate * network[i][neuron]['delta']

# %%
# Train a network for a fixed number of epochs
def train_network(network, train, l_rate, n_epoch, n_outputs, W):
  for epoch in range(n_epoch):
    sum_error = 0
    for row in train:
      outputs = forward_propagate(network, row) # final output from output layer
      expected = [0 for i in range(n_outputs)] 
      expected[row[-1]] = 1 
      sum_error += sum([(expected[i]-outputs[i])**2 for i in range(len(expected))]) # squired sum of total error in output:  sum((y'-y) squire)
      backward_propagate_error(network, expected)
      update_weights(network, row, l_rate, W)
    print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))
  return expected, row

# %%
def test_network(network, test_data):
  # for epoch in range(n_epoch):
  #   sum_error = 0
  for row in test_data:
    outputs = forward_propagate(network, row) # final output from output layer
    # expected = [0 for i in range(n_outputs)] 
    # expected[row[-1]] = 1 
    # sum_error += sum([(expected[i]-outputs[i])**2 for i in range(len(expected))]) # squired sum of total error in output:  sum((y'-y) squire)
    # backward_propagate_error(network, expected)
    # update_weights(network, row, l_rate, W)
    print("outputs:",outputs)

# %%
# Test training backprop algorithm
seed(10)
dataset = [[2.7810836,2.550537003,0],
	[1.465489372,2.362125076,0],
	[3.396561688,4.400293529,0],
	[1.38807019,1.850220317,0],
	[3.06407232,3.005305973,0],
	[7.627531214,2.759262235,1],
	[5.332441248,2.088626775,1],
	[6.922596716,1.77106367,1],
	[8.675418651,-0.242068655,1],
	[7.673756466,3.508563011,1]]
n_inputs = len(dataset[0]) - 1
n_outputs = len(set([row[-1] for row in dataset]))
network = initialize_network(n_inputs, n_outputs)

# %% [markdown]
# embed watermark

# %%
# watermark
X=[0.9, 0.76, 0.48]

# selected weights from each layer to be watermarked
W= dict()
W[0]=[1,0] 
W[1]=[1,1]
W[2]=[1,2]

# update the weight located in W
for item in range(len(W)):
  layer = item
  mu = 0.1
  sigma = 0.001
  neuron_with_weight=W[item]
  value_of_selected_weight = network[layer][neuron_with_weight[0]]['weights'][neuron_with_weight[1]]
  print("before update layer", layer, "neuron", neuron_with_weight[0],"weight index", neuron_with_weight[1], "->", value_of_selected_weight)
  value_of_selected_weight = 2*sigma*(X[item] - 0.5) + mu
  network[layer][neuron_with_weight[0]]['weights'][neuron_with_weight[1]] = value_of_selected_weight
  print("after update layer ", layer, "neuron", neuron_with_weight[0],"weight index", neuron_with_weight[1], "->", network[layer][neuron_with_weight[0]]['weights'][neuron_with_weight[1]])
# Out:
# before update layer 0 neuron 1 weight index 0 -> 0.006548326221975255
# after update layer  0 neuron 1 weight index 0 -> 0.1008
# before update layer 1 neuron 1 weight index 1 -> 0.006313146269974237
# after update layer  1 neuron 1 weight index 1 -> 0.10052000000000001
# before update layer 2 neuron 1 weight index 2 -> 0.02531908498698365
# after update layer  2 neuron 1 weight index 2 -> 0.09996000000000001

# %%
# after updating the weight
for layer in network:
	print(layer)
# Out:
# [{'weights': [0.011518163119584555, 0.00036012637945079826, -0.0006068413742203497]}, {'weights': [0.1008, 0.008238627772396654, 0.0008448564850340855]}, {'weights': [0.006441188085708311, -0.009170587757917082, -0.005592826757153489]}, {'weights': [0.010108626284691178, -0.0037411235406674616, -0.005874669122090942]}, {'weights': [0.0047172652277122275, 0.0004355496136894334, -0.0017796355356050376]}, {'weights': [0.013175080920362982, -0.007364942988887214, -0.017398847540954637]}, {'weights': [-0.010833929954158297, 0.012886891197422845, 0.00046499251978211504]}]
# [{'weights': [-0.016544040163402364, -0.0023141989075542665, 0.01414984305341131, -0.008955984319255796, -0.008968272212101586, -6.629927217613041e-05, 0.0017490786481609564, -0.008551237394299369]}, {'weights': [0.01402191064982743, 0.10052000000000001, 0.015002614946360916, -0.014695820432736295, 0.0004230730245053447, -0.0015703272686653398, 0.003717656325967631, -0.016813239589524874]}, {'weights': [0.01268335791645142, -0.022067911309209577, 0.00011858846741417564, 0.007088440642415492, 0.003320314337622807, 0.008546222928617894, 0.019169167625318288, 0.005383288707378535]}, {'weights': [-0.015400981233734005, -0.0037148707186170126, 0.010195143594792072, 0.0003576660408715391, -0.008455765399539928, 0.0025087499252305803, 0.007172565872845864, 0.013092311907188901]}, {'weights': [0.009001400386976595, -0.007567351133513712, -0.006684440292052067, -0.004058790809636131, -0.02227244223242944, -0.02045678063636229, -0.02167863852987757, -0.0035705899339424354]}]
# [{'weights': [-0.001827722430928145, 0.00716422586555198, -0.0004286120422808521, -0.0007974090067309083, 0.013452900999247331, 0.0003130410034155977]}, {'weights': [0.005129939466933286, 0.012065567734128946, 0.09996000000000001, -0.005925698674478722, -0.0031110629501135273, -0.003788001614285877]}, {'weights': [0.012546690487930362, -0.00044831513888836524, 0.004747314844750687, 0.005542728507178772, 0.02236640084350899, -0.0006325013506847258]}]
# [{'weights': [0.005310838160022837, 0.007583674098021661, -0.010677814807988958, 0.01882741353580257]}, {'weights': [-0.0005559434368296441, -0.004261659192603658, 0.013120123164742464, -0.01263854507448843]}]

# %% [markdown]
# train the model

# %%
# train the network
expected_output, row = train_network(network, dataset, 0.1, 5000, n_outputs, W)
# Out:
# Streaming output truncated to the last 5000 lines.
# >epoch=0, lrate=0.100, error=5.069
# >epoch=1, lrate=0.100, error=5.069
# >epoch=2, lrate=0.100, error=5.070
# >epoch=3, lrate=0.100, error=5.070
# >epoch=4, lrate=0.100, error=5.071
# >epoch=5, lrate=0.100, error=5.071
# >epoch=6, lrate=0.100, error=5.072
# >epoch=7, lrate=0.100, error=5.072
# >epoch=8, lrate=0.100, error=5.073
# >epoch=9, lrate=0.100, error=5.073
# >epoch=10, lrate=0.100, error=5.074
# >epoch=11, lrate=0.100, error=5.074
# >epoch=12, lrate=0.100, error=5.074
# >epoch=13, lrate=0.100, error=5.075
# >epoch=14, lrate=0.100, error=5.075
# >epoch=15, lrate=0.100, error=5.075
# >epoch=16, lrate=0.100, error=5.075
# >epoch=17, lrate=0.100, error=5.075
# >epoch=18, lrate=0.100, error=5.076
# >epoch=19, lrate=0.100, error=5.076
# >epoch=20, lrate=0.100, error=5.076
# >epoch=21, lrate=0.100, error=5.076
# >epoch=22, lrate=0.100, error=5.076
# >epoch=23, lrate=0.100, error=5.076
# >epoch=24, lrate=0.100, error=5.076
# >epoch=25, lrate=0.100, error=5.076
# >epoch=26, lrate=0.100, error=5.076
# >epoch=27, lrate=0.100, error=5.076
# >epoch=28, lrate=0.100, error=5.076
# >epoch=29, lrate=0.100, error=5.076
# >epoch=30, lrate=0.100, error=5.076
# >epoch=31, lrate=0.100, error=5.076
# >epoch=32, lrate=0.100, error=5.076
# >epoch=33, lrate=0.100, error=5.076
# >epoch=34, lrate=0.100, error=5.076
# >epoch=35, lrate=0.100, error=5.076
# >epoch=36, lrate=0.100, error=5.076
# >epoch=37, lrate=0.100, error=5.076
# >epoch=38, lrate=0.100, error=5.076
# >epoch=39, lrate=0.100, error=5.076
# >epoch=40, lrate=0.100, error=5.076
# >epoch=41, lrate=0.100, error=5.076
# >epoch=42, lrate=0.100, error=5.076
# >epoch=43, lrate=0.100, error=5.076
# >epoch=44, lrate=0.100, error=5.076
# >epoch=45, lrate=0.100, error=5.076
# >epoch=46, lrate=0.100, error=5.076
# >epoch=47, lrate=0.100, error=5.076
# >epoch=48, lrate=0.100, error=5.076
# >epoch=49, lrate=0.100, error=5.076
# >epoch=50, lrate=0.100, error=5.076
# >epoch=51, lrate=0.100, error=5.076
# >epoch=52, lrate=0.100, error=5.076
# >epoch=53, lrate=0.100, error=5.076
# >epoch=54, lrate=0.100, error=5.076
# >epoch=55, lrate=0.100, error=5.076
# >epoch=56, lrate=0.100, error=5.075
# >epoch=57, lrate=0.100, error=5.075
# >epoch=58, lrate=0.100, error=5.075
# >epoch=59, lrate=0.100, error=5.075
# >epoch=60, lrate=0.100, error=5.075
# >epoch=61, lrate=0.100, error=5.075
# >epoch=62, lrate=0.100, error=5.075
# >epoch=63, lrate=0.100, error=5.075
# >epoch=64, lrate=0.100, error=5.075
# >epoch=65, lrate=0.100, error=5.075
# >epoch=66, lrate=0.100, error=5.075
# >epoch=67, lrate=0.100, error=5.075
# >epoch=68, lrate=0.100, error=5.075
# >epoch=69, lrate=0.100, error=5.075
# >epoch=70, lrate=0.100, error=5.075
# >epoch=71, lrate=0.100, error=5.075
# >epoch=72, lrate=0.100, error=5.075
# >epoch=73, lrate=0.100, error=5.075
# >epoch=74, lrate=0.100, error=5.075
# >epoch=75, lrate=0.100, error=5.075
# >epoch=76, lrate=0.100, error=5.075
# >epoch=77, lrate=0.100, error=5.075
# >epoch=78, lrate=0.100, error=5.075
# >epoch=79, lrate=0.100, error=5.075
# >epoch=80, lrate=0.100, error=5.075
# >epoch=81, lrate=0.100, error=5.075
# >epoch=82, lrate=0.100, error=5.075
# >epoch=83, lrate=0.100, error=5.075
# >epoch=84, lrate=0.100, error=5.075
# >epoch=85, lrate=0.100, error=5.075
# >epoch=86, lrate=0.100, error=5.075
# >epoch=87, lrate=0.100, error=5.075
# >epoch=88, lrate=0.100, error=5.075
# >epoch=89, lrate=0.100, error=5.075
# >epoch=90, lrate=0.100, error=5.074
# >epoch=91, lrate=0.100, error=5.074
# >epoch=92, lrate=0.100, error=5.074
# >epoch=93, lrate=0.100, error=5.074
# >epoch=94, lrate=0.100, error=5.074
# >epoch=95, lrate=0.100, error=5.074
# >epoch=96, lrate=0.100, error=5.074
# >epoch=97, lrate=0.100, error=5.074
# >epoch=98, lrate=0.100, error=5.074
# >epoch=99, lrate=0.100, error=5.074
# >epoch=100, lrate=0.100, error=5.074
# >epoch=101, lrate=0.100, error=5.074
# >epoch=102, lrate=0.100, error=5.074
# >epoch=103, lrate=0.100, error=5.074
# >epoch=104, lrate=0.100, error=5.074
# >epoch=105, lrate=0.100, error=5.074
# >epoch=106, lrate=0.100, error=5.074
# >epoch=107, lrate=0.100, error=5.074
# >epoch=108, lrate=0.100, error=5.074
# >epoch=109, lrate=0.100, error=5.074
# >epoch=110, lrate=0.100, error=5.074
# >epoch=111, lrate=0.100, error=5.074
# >epoch=112, lrate=0.100, error=5.074
# >epoch=113, lrate=0.100, error=5.074
# >epoch=114, lrate=0.100, error=5.074
# >epoch=115, lrate=0.100, error=5.074
# >epoch=116, lrate=0.100, error=5.074
# >epoch=117, lrate=0.100, error=5.074
# >epoch=118, lrate=0.100, error=5.074
# >epoch=119, lrate=0.100, error=5.074
# >epoch=120, lrate=0.100, error=5.074
# >epoch=121, lrate=0.100, error=5.074
# >epoch=122, lrate=0.100, error=5.074
# >epoch=123, lrate=0.100, error=5.074
# >epoch=124, lrate=0.100, error=5.073
# >epoch=125, lrate=0.100, error=5.073
# >epoch=126, lrate=0.100, error=5.073
# >epoch=127, lrate=0.100, error=5.073
# >epoch=128, lrate=0.100, error=5.073
# >epoch=129, lrate=0.100, error=5.073
# >epoch=130, lrate=0.100, error=5.073
# >epoch=131, lrate=0.100, error=5.073
# >epoch=132, lrate=0.100, error=5.073
# >epoch=133, lrate=0.100, error=5.073
# >epoch=134, lrate=0.100, error=5.073
# >epoch=135, lrate=0.100, error=5.073
# >epoch=136, lrate=0.100, error=5.073
# >epoch=137, lrate=0.100, error=5.073
# >epoch=138, lrate=0.100, error=5.073
# >epoch=139, lrate=0.100, error=5.073
# >epoch=140, lrate=0.100, error=5.073
# >epoch=141, lrate=0.100, error=5.073
# >epoch=142, lrate=0.100, error=5.073
# >epoch=143, lrate=0.100, error=5.073
# >epoch=144, lrate=0.100, error=5.073
# >epoch=145, lrate=0.100, error=5.073
# >epoch=146, lrate=0.100, error=5.073
# >epoch=147, lrate=0.100, error=5.073
# >epoch=148, lrate=0.100, error=5.073
# >epoch=149, lrate=0.100, error=5.073
# >epoch=150, lrate=0.100, error=5.073
# >epoch=151, lrate=0.100, error=5.073
# >epoch=152, lrate=0.100, error=5.073
# >epoch=153, lrate=0.100, error=5.073
# >epoch=154, lrate=0.100, error=5.073
# >epoch=155, lrate=0.100, error=5.073
# >epoch=156, lrate=0.100, error=5.073
# >epoch=157, lrate=0.100, error=5.073
# >epoch=158, lrate=0.100, error=5.072
# >epoch=159, lrate=0.100, error=5.072
# >epoch=160, lrate=0.100, error=5.072
# >epoch=161, lrate=0.100, error=5.072
# >epoch=162, lrate=0.100, error=5.072
# >epoch=163, lrate=0.100, error=5.072
# >epoch=164, lrate=0.100, error=5.072
# >epoch=165, lrate=0.100, error=5.072
# >epoch=166, lrate=0.100, error=5.072
# >epoch=167, lrate=0.100, error=5.072
# >epoch=168, lrate=0.100, error=5.072
# >epoch=169, lrate=0.100, error=5.072
# >epoch=170, lrate=0.100, error=5.072
# >epoch=171, lrate=0.100, error=5.072
# >epoch=172, lrate=0.100, error=5.072
# >epoch=173, lrate=0.100, error=5.072
# >epoch=174, lrate=0.100, error=5.072
# >epoch=175, lrate=0.100, error=5.072
# >epoch=176, lrate=0.100, error=5.072
# >epoch=177, lrate=0.100, error=5.072
# >epoch=178, lrate=0.100, error=5.072
# >epoch=179, lrate=0.100, error=5.072
# >epoch=180, lrate=0.100, error=5.072
# >epoch=181, lrate=0.100, error=5.072
# >epoch=182, lrate=0.100, error=5.072
# >epoch=183, lrate=0.100, error=5.072
# >epoch=184, lrate=0.100, error=5.072
# >epoch=185, lrate=0.100, error=5.072
# >epoch=186, lrate=0.100, error=5.072
# >epoch=187, lrate=0.100, error=5.072
# >epoch=188, lrate=0.100, error=5.072
# >epoch=189, lrate=0.100, error=5.072
# >epoch=190, lrate=0.100, error=5.072
# >epoch=191, lrate=0.100, error=5.072
# >epoch=192, lrate=0.100, error=5.071
# >epoch=193, lrate=0.100, error=5.071
# >epoch=194, lrate=0.100, error=5.071
# >epoch=195, lrate=0.100, error=5.071
# >epoch=196, lrate=0.100, error=5.071
# >epoch=197, lrate=0.100, error=5.071
# >epoch=198, lrate=0.100, error=5.071
# >epoch=199, lrate=0.100, error=5.071
# >epoch=200, lrate=0.100, error=5.071
# >epoch=201, lrate=0.100, error=5.071
# >epoch=202, lrate=0.100, error=5.071
# >epoch=203, lrate=0.100, error=5.071
# >epoch=204, lrate=0.100, error=5.071
# >epoch=205, lrate=0.100, error=5.071
# >epoch=206, lrate=0.100, error=5.071
# >epoch=207, lrate=0.100, error=5.071
# >epoch=208, lrate=0.100, error=5.071
# >epoch=209, lrate=0.100, error=5.071
# >epoch=210, lrate=0.100, error=5.071
# >epoch=211, lrate=0.100, error=5.071
# >epoch=212, lrate=0.100, error=5.071
# >epoch=213, lrate=0.100, error=5.071
# >epoch=214, lrate=0.100, error=5.071
# >epoch=215, lrate=0.100, error=5.071
# >epoch=216, lrate=0.100, error=5.071
# >epoch=217, lrate=0.100, error=5.071
# >epoch=218, lrate=0.100, error=5.071
# >epoch=219, lrate=0.100, error=5.071
# >epoch=220, lrate=0.100, error=5.071
# >epoch=221, lrate=0.100, error=5.071
# >epoch=222, lrate=0.100, error=5.071
# >epoch=223, lrate=0.100, error=5.071
# >epoch=224, lrate=0.100, error=5.071
# >epoch=225, lrate=0.100, error=5.071
# >epoch=226, lrate=0.100, error=5.071
# >epoch=227, lrate=0.100, error=5.070
# >epoch=228, lrate=0.100, error=5.070
# >epoch=229, lrate=0.100, error=5.070
# >epoch=230, lrate=0.100, error=5.070
# >epoch=231, lrate=0.100, error=5.070
# >epoch=232, lrate=0.100, error=5.070
# >epoch=233, lrate=0.100, error=5.070
# >epoch=234, lrate=0.100, error=5.070
# >epoch=235, lrate=0.100, error=5.070
# >epoch=236, lrate=0.100, error=5.070
# >epoch=237, lrate=0.100, error=5.070
# >epoch=238, lrate=0.100, error=5.070
# >epoch=239, lrate=0.100, error=5.070
# >epoch=240, lrate=0.100, error=5.070
# >epoch=241, lrate=0.100, error=5.070
# >epoch=242, lrate=0.100, error=5.070
# >epoch=243, lrate=0.100, error=5.070
# >epoch=244, lrate=0.100, error=5.070
# >epoch=245, lrate=0.100, error=5.070
# >epoch=246, lrate=0.100, error=5.070
# >epoch=247, lrate=0.100, error=5.070
# >epoch=248, lrate=0.100, error=5.070
# >epoch=249, lrate=0.100, error=5.070
# >epoch=250, lrate=0.100, error=5.070
# >epoch=251, lrate=0.100, error=5.070
# >epoch=252, lrate=0.100, error=5.070
# >epoch=253, lrate=0.100, error=5.070
# >epoch=254, lrate=0.100, error=5.070
# >epoch=255, lrate=0.100, error=5.070
# >epoch=256, lrate=0.100, error=5.070
# >epoch=257, lrate=0.100, error=5.070
# >epoch=258, lrate=0.100, error=5.070
# >epoch=259, lrate=0.100, error=5.070
# >epoch=260, lrate=0.100, error=5.070
# >epoch=261, lrate=0.100, error=5.069
# >epoch=262, lrate=0.100, error=5.069
# >epoch=263, lrate=0.100, error=5.069
# >epoch=264, lrate=0.100, error=5.069
# >epoch=265, lrate=0.100, error=5.069
# >epoch=266, lrate=0.100, error=5.069
# >epoch=267, lrate=0.100, error=5.069
# >epoch=268, lrate=0.100, error=5.069
# >epoch=269, lrate=0.100, error=5.069
# >epoch=270, lrate=0.100, error=5.069
# >epoch=271, lrate=0.100, error=5.069
# >epoch=272, lrate=0.100, error=5.069
# >epoch=273, lrate=0.100, error=5.069
# >epoch=274, lrate=0.100, error=5.069
# >epoch=275, lrate=0.100, error=5.069
# >epoch=276, lrate=0.100, error=5.069
# >epoch=277, lrate=0.100, error=5.069
# >epoch=278, lrate=0.100, error=5.069
# >epoch=279, lrate=0.100, error=5.069
# >epoch=280, lrate=0.100, error=5.069
# >epoch=281, lrate=0.100, error=5.069
# >epoch=282, lrate=0.100, error=5.069
# >epoch=283, lrate=0.100, error=5.069
# >epoch=284, lrate=0.100, error=5.069
# >epoch=285, lrate=0.100, error=5.069
# >epoch=286, lrate=0.100, error=5.069
# >epoch=287, lrate=0.100, error=5.069
# >epoch=288, lrate=0.100, error=5.069
# >epoch=289, lrate=0.100, error=5.069
# >epoch=290, lrate=0.100, error=5.069
# >epoch=291, lrate=0.100, error=5.069
# >epoch=292, lrate=0.100, error=5.069
# >epoch=293, lrate=0.100, error=5.069
# >epoch=294, lrate=0.100, error=5.069
# >epoch=295, lrate=0.100, error=5.069
# >epoch=296, lrate=0.100, error=5.068
# >epoch=297, lrate=0.100, error=5.068
# >epoch=298, lrate=0.100, error=5.068
# >epoch=299, lrate=0.100, error=5.068
# >epoch=300, lrate=0.100, error=5.068
# >epoch=301, lrate=0.100, error=5.068
# >epoch=302, lrate=0.100, error=5.068
# >epoch=303, lrate=0.100, error=5.068
# >epoch=304, lrate=0.100, error=5.068
# >epoch=305, lrate=0.100, error=5.068
# >epoch=306, lrate=0.100, error=5.068
# >epoch=307, lrate=0.100, error=5.068
# >epoch=308, lrate=0.100, error=5.068
# >epoch=309, lrate=0.100, error=5.068
# >epoch=310, lrate=0.100, error=5.068
# >epoch=311, lrate=0.100, error=5.068
# >epoch=312, lrate=0.100, error=5.068
# >epoch=313, lrate=0.100, error=5.068
# >epoch=314, lrate=0.100, error=5.068
# >epoch=315, lrate=0.100, error=5.068
# >epoch=316, lrate=0.100, error=5.068
# >epoch=317, lrate=0.100, error=5.068
# >epoch=318, lrate=0.100, error=5.068
# >epoch=319, lrate=0.100, error=5.068
# >epoch=320, lrate=0.100, error=5.068
# >epoch=321, lrate=0.100, error=5.068
# >epoch=322, lrate=0.100, error=5.068
# >epoch=323, lrate=0.100, error=5.068
# >epoch=324, lrate=0.100, error=5.068
# >epoch=325, lrate=0.100, error=5.068
# >epoch=326, lrate=0.100, error=5.068
# >epoch=327, lrate=0.100, error=5.068
# >epoch=328, lrate=0.100, error=5.068
# >epoch=329, lrate=0.100, error=5.068
# >epoch=330, lrate=0.100, error=5.068
# >epoch=331, lrate=0.100, error=5.068
# >epoch=332, lrate=0.100, error=5.067
# >epoch=333, lrate=0.100, error=5.067
# >epoch=334, lrate=0.100, error=5.067
# >epoch=335, lrate=0.100, error=5.067
# >epoch=336, lrate=0.100, error=5.067
# >epoch=337, lrate=0.100, error=5.067
# >epoch=338, lrate=0.100, error=5.067
# >epoch=339, lrate=0.100, error=5.067
# >epoch=340, lrate=0.100, error=5.067
# >epoch=341, lrate=0.100, error=5.067
# >epoch=342, lrate=0.100, error=5.067
# >epoch=343, lrate=0.100, error=5.067
# >epoch=344, lrate=0.100, error=5.067
# >epoch=345, lrate=0.100, error=5.067
# >epoch=346, lrate=0.100, error=5.067
# >epoch=347, lrate=0.100, error=5.067
# >epoch=348, lrate=0.100, error=5.067
# >epoch=349, lrate=0.100, error=5.067
# >epoch=350, lrate=0.100, error=5.067
# >epoch=351, lrate=0.100, error=5.067
# >epoch=352, lrate=0.100, error=5.067
# >epoch=353, lrate=0.100, error=5.067
# >epoch=354, lrate=0.100, error=5.067
# >epoch=355, lrate=0.100, error=5.067
# >epoch=356, lrate=0.100, error=5.067
# >epoch=357, lrate=0.100, error=5.067
# >epoch=358, lrate=0.100, error=5.067
# >epoch=359, lrate=0.100, error=5.067
# >epoch=360, lrate=0.100, error=5.067
# >epoch=361, lrate=0.100, error=5.067
# >epoch=362, lrate=0.100, error=5.067
# >epoch=363, lrate=0.100, error=5.067
# >epoch=364, lrate=0.100, error=5.067
# >epoch=365, lrate=0.100, error=5.067
# >epoch=366, lrate=0.100, error=5.067
# >epoch=367, lrate=0.100, error=5.067
# >epoch=368, lrate=0.100, error=5.066
# >epoch=369, lrate=0.100, error=5.066
# >epoch=370, lrate=0.100, error=5.066
# >epoch=371, lrate=0.100, error=5.066
# >epoch=372, lrate=0.100, error=5.066
# >epoch=373, lrate=0.100, error=5.066
# >epoch=374, lrate=0.100, error=5.066
# >epoch=375, lrate=0.100, error=5.066
# >epoch=376, lrate=0.100, error=5.066
# >epoch=377, lrate=0.100, error=5.066
# >epoch=378, lrate=0.100, error=5.066
# >epoch=379, lrate=0.100, error=5.066
# >epoch=380, lrate=0.100, error=5.066
# >epoch=381, lrate=0.100, error=5.066
# >epoch=382, lrate=0.100, error=5.066
# >epoch=383, lrate=0.100, error=5.066
# >epoch=384, lrate=0.100, error=5.066
# >epoch=385, lrate=0.100, error=5.066
# >epoch=386, lrate=0.100, error=5.066
# >epoch=387, lrate=0.100, error=5.066
# >epoch=388, lrate=0.100, error=5.066
# >epoch=389, lrate=0.100, error=5.066
# >epoch=390, lrate=0.100, error=5.066
# >epoch=391, lrate=0.100, error=5.066
# >epoch=392, lrate=0.100, error=5.066
# >epoch=393, lrate=0.100, error=5.066
# >epoch=394, lrate=0.100, error=5.066
# >epoch=395, lrate=0.100, error=5.066
# >epoch=396, lrate=0.100, error=5.066
# >epoch=397, lrate=0.100, error=5.066
# >epoch=398, lrate=0.100, error=5.066
# >epoch=399, lrate=0.100, error=5.066
# >epoch=400, lrate=0.100, error=5.066
# >epoch=401, lrate=0.100, error=5.066
# >epoch=402, lrate=0.100, error=5.066
# >epoch=403, lrate=0.100, error=5.066
# >epoch=404, lrate=0.100, error=5.065
# >epoch=405, lrate=0.100, error=5.065
# >epoch=406, lrate=0.100, error=5.065
# >epoch=407, lrate=0.100, error=5.065
# >epoch=408, lrate=0.100, error=5.065
# >epoch=409, lrate=0.100, error=5.065
# >epoch=410, lrate=0.100, error=5.065
# >epoch=411, lrate=0.100, error=5.065
# >epoch=412, lrate=0.100, error=5.065
# >epoch=413, lrate=0.100, error=5.065
# >epoch=414, lrate=0.100, error=5.065
# >epoch=415, lrate=0.100, error=5.065
# >epoch=416, lrate=0.100, error=5.065
# >epoch=417, lrate=0.100, error=5.065
# >epoch=418, lrate=0.100, error=5.065
# >epoch=419, lrate=0.100, error=5.065
# >epoch=420, lrate=0.100, error=5.065
# >epoch=421, lrate=0.100, error=5.065
# >epoch=422, lrate=0.100, error=5.065
# >epoch=423, lrate=0.100, error=5.065
# >epoch=424, lrate=0.100, error=5.065
# >epoch=425, lrate=0.100, error=5.065
# >epoch=426, lrate=0.100, error=5.065
# >epoch=427, lrate=0.100, error=5.065
# >epoch=428, lrate=0.100, error=5.065
# >epoch=429, lrate=0.100, error=5.065
# >epoch=430, lrate=0.100, error=5.065
# >epoch=431, lrate=0.100, error=5.065
# >epoch=432, lrate=0.100, error=5.065
# >epoch=433, lrate=0.100, error=5.065
# >epoch=434, lrate=0.100, error=5.065
# >epoch=435, lrate=0.100, error=5.065
# >epoch=436, lrate=0.100, error=5.065
# >epoch=437, lrate=0.100, error=5.065
# >epoch=438, lrate=0.100, error=5.065
# >epoch=439, lrate=0.100, error=5.065
# >epoch=440, lrate=0.100, error=5.065
# >epoch=441, lrate=0.100, error=5.064
# >epoch=442, lrate=0.100, error=5.064
# >epoch=443, lrate=0.100, error=5.064
# >epoch=444, lrate=0.100, error=5.064
# >epoch=445, lrate=0.100, error=5.064
# >epoch=446, lrate=0.100, error=5.064
# >epoch=447, lrate=0.100, error=5.064
# >epoch=448, lrate=0.100, error=5.064
# >epoch=449, lrate=0.100, error=5.064
# >epoch=450, lrate=0.100, error=5.064
# >epoch=451, lrate=0.100, error=5.064
# >epoch=452, lrate=0.100, error=5.064
# >epoch=453, lrate=0.100, error=5.064
# >epoch=454, lrate=0.100, error=5.064
# >epoch=455, lrate=0.100, error=5.064
# >epoch=456, lrate=0.100, error=5.064
# >epoch=457, lrate=0.100, error=5.064
# >epoch=458, lrate=0.100, error=5.064
# >epoch=459, lrate=0.100, error=5.064
# >epoch=460, lrate=0.100, error=5.064
# >epoch=461, lrate=0.100, error=5.064
# >epoch=462, lrate=0.100, error=5.064
# >epoch=463, lrate=0.100, error=5.064
# >epoch=464, lrate=0.100, error=5.064
# >epoch=465, lrate=0.100, error=5.064
# >epoch=466, lrate=0.100, error=5.064
# >epoch=467, lrate=0.100, error=5.064
# >epoch=468, lrate=0.100, error=5.064
# >epoch=469, lrate=0.100, error=5.064
# >epoch=470, lrate=0.100, error=5.064
# >epoch=471, lrate=0.100, error=5.064
# >epoch=472, lrate=0.100, error=5.064
# >epoch=473, lrate=0.100, error=5.064
# >epoch=474, lrate=0.100, error=5.064
# >epoch=475, lrate=0.100, error=5.064
# >epoch=476, lrate=0.100, error=5.064
# >epoch=477, lrate=0.100, error=5.064
# >epoch=478, lrate=0.100, error=5.064
# >epoch=479, lrate=0.100, error=5.063
# >epoch=480, lrate=0.100, error=5.063
# >epoch=481, lrate=0.100, error=5.063
# >epoch=482, lrate=0.100, error=5.063
# >epoch=483, lrate=0.100, error=5.063
# >epoch=484, lrate=0.100, error=5.063
# >epoch=485, lrate=0.100, error=5.063
# >epoch=486, lrate=0.100, error=5.063
# >epoch=487, lrate=0.100, error=5.063
# >epoch=488, lrate=0.100, error=5.063
# >epoch=489, lrate=0.100, error=5.063
# >epoch=490, lrate=0.100, error=5.063
# >epoch=491, lrate=0.100, error=5.063
# >epoch=492, lrate=0.100, error=5.063
# >epoch=493, lrate=0.100, error=5.063
# >epoch=494, lrate=0.100, error=5.063
# >epoch=495, lrate=0.100, error=5.063
# >epoch=496, lrate=0.100, error=5.063
# >epoch=497, lrate=0.100, error=5.063
# >epoch=498, lrate=0.100, error=5.063
# >epoch=499, lrate=0.100, error=5.063
# >epoch=500, lrate=0.100, error=5.063
# >epoch=501, lrate=0.100, error=5.063
# >epoch=502, lrate=0.100, error=5.063
# >epoch=503, lrate=0.100, error=5.063
# >epoch=504, lrate=0.100, error=5.063
# >epoch=505, lrate=0.100, error=5.063
# >epoch=506, lrate=0.100, error=5.063
# >epoch=507, lrate=0.100, error=5.063
# >epoch=508, lrate=0.100, error=5.063
# >epoch=509, lrate=0.100, error=5.063
# >epoch=510, lrate=0.100, error=5.063
# >epoch=511, lrate=0.100, error=5.063
# >epoch=512, lrate=0.100, error=5.063
# >epoch=513, lrate=0.100, error=5.063
# >epoch=514, lrate=0.100, error=5.063
# >epoch=515, lrate=0.100, error=5.063
# >epoch=516, lrate=0.100, error=5.063
# >epoch=517, lrate=0.100, error=5.063
# >epoch=518, lrate=0.100, error=5.062
# >epoch=519, lrate=0.100, error=5.062
# >epoch=520, lrate=0.100, error=5.062
# >epoch=521, lrate=0.100, error=5.062
# >epoch=522, lrate=0.100, error=5.062
# >epoch=523, lrate=0.100, error=5.062
# >epoch=524, lrate=0.100, error=5.062
# >epoch=525, lrate=0.100, error=5.062
# >epoch=526, lrate=0.100, error=5.062
# >epoch=527, lrate=0.100, error=5.062
# >epoch=528, lrate=0.100, error=5.062
# >epoch=529, lrate=0.100, error=5.062
# >epoch=530, lrate=0.100, error=5.062
# >epoch=531, lrate=0.100, error=5.062
# >epoch=532, lrate=0.100, error=5.062
# >epoch=533, lrate=0.100, error=5.062
# >epoch=534, lrate=0.100, error=5.062
# >epoch=535, lrate=0.100, error=5.062
# >epoch=536, lrate=0.100, error=5.062
# >epoch=537, lrate=0.100, error=5.062
# >epoch=538, lrate=0.100, error=5.062
# >epoch=539, lrate=0.100, error=5.062
# >epoch=540, lrate=0.100, error=5.062
# >epoch=541, lrate=0.100, error=5.062
# >epoch=542, lrate=0.100, error=5.062
# >epoch=543, lrate=0.100, error=5.062
# >epoch=544, lrate=0.100, error=5.062
# >epoch=545, lrate=0.100, error=5.062
# >epoch=546, lrate=0.100, error=5.062
# >epoch=547, lrate=0.100, error=5.062
# >epoch=548, lrate=0.100, error=5.062
# >epoch=549, lrate=0.100, error=5.062
# >epoch=550, lrate=0.100, error=5.062
# >epoch=551, lrate=0.100, error=5.062
# >epoch=552, lrate=0.100, error=5.062
# >epoch=553, lrate=0.100, error=5.062
# >epoch=554, lrate=0.100, error=5.062
# >epoch=555, lrate=0.100, error=5.062
# >epoch=556, lrate=0.100, error=5.062
# >epoch=557, lrate=0.100, error=5.061
# >epoch=558, lrate=0.100, error=5.061
# >epoch=559, lrate=0.100, error=5.061
# >epoch=560, lrate=0.100, error=5.061
# >epoch=561, lrate=0.100, error=5.061
# >epoch=562, lrate=0.100, error=5.061
# >epoch=563, lrate=0.100, error=5.061
# >epoch=564, lrate=0.100, error=5.061
# >epoch=565, lrate=0.100, error=5.061
# >epoch=566, lrate=0.100, error=5.061
# >epoch=567, lrate=0.100, error=5.061
# >epoch=568, lrate=0.100, error=5.061
# >epoch=569, lrate=0.100, error=5.061
# >epoch=570, lrate=0.100, error=5.061
# >epoch=571, lrate=0.100, error=5.061
# >epoch=572, lrate=0.100, error=5.061
# >epoch=573, lrate=0.100, error=5.061
# >epoch=574, lrate=0.100, error=5.061
# >epoch=575, lrate=0.100, error=5.061
# >epoch=576, lrate=0.100, error=5.061
# >epoch=577, lrate=0.100, error=5.061
# >epoch=578, lrate=0.100, error=5.061
# >epoch=579, lrate=0.100, error=5.061
# >epoch=580, lrate=0.100, error=5.061
# >epoch=581, lrate=0.100, error=5.061
# >epoch=582, lrate=0.100, error=5.061
# >epoch=583, lrate=0.100, error=5.061
# >epoch=584, lrate=0.100, error=5.061
# >epoch=585, lrate=0.100, error=5.061
# >epoch=586, lrate=0.100, error=5.061
# >epoch=587, lrate=0.100, error=5.061
# >epoch=588, lrate=0.100, error=5.061
# >epoch=589, lrate=0.100, error=5.061
# >epoch=590, lrate=0.100, error=5.061
# >epoch=591, lrate=0.100, error=5.061
# >epoch=592, lrate=0.100, error=5.061
# >epoch=593, lrate=0.100, error=5.061
# >epoch=594, lrate=0.100, error=5.061
# >epoch=595, lrate=0.100, error=5.061
# >epoch=596, lrate=0.100, error=5.061
# >epoch=597, lrate=0.100, error=5.060
# >epoch=598, lrate=0.100, error=5.060
# >epoch=599, lrate=0.100, error=5.060
# >epoch=600, lrate=0.100, error=5.060
# >epoch=601, lrate=0.100, error=5.060
# >epoch=602, lrate=0.100, error=5.060
# >epoch=603, lrate=0.100, error=5.060
# >epoch=604, lrate=0.100, error=5.060
# >epoch=605, lrate=0.100, error=5.060
# >epoch=606, lrate=0.100, error=5.060
# >epoch=607, lrate=0.100, error=5.060
# >epoch=608, lrate=0.100, error=5.060
# >epoch=609, lrate=0.100, error=5.060
# >epoch=610, lrate=0.100, error=5.060
# >epoch=611, lrate=0.100, error=5.060
# >epoch=612, lrate=0.100, error=5.060
# >epoch=613, lrate=0.100, error=5.060
# >epoch=614, lrate=0.100, error=5.060
# >epoch=615, lrate=0.100, error=5.060
# >epoch=616, lrate=0.100, error=5.060
# >epoch=617, lrate=0.100, error=5.060
# >epoch=618, lrate=0.100, error=5.060
# >epoch=619, lrate=0.100, error=5.060
# >epoch=620, lrate=0.100, error=5.060
# >epoch=621, lrate=0.100, error=5.060
# >epoch=622, lrate=0.100, error=5.060
# >epoch=623, lrate=0.100, error=5.060
# >epoch=624, lrate=0.100, error=5.060
# >epoch=625, lrate=0.100, error=5.060
# >epoch=626, lrate=0.100, error=5.060
# >epoch=627, lrate=0.100, error=5.060
# >epoch=628, lrate=0.100, error=5.060
# >epoch=629, lrate=0.100, error=5.060
# >epoch=630, lrate=0.100, error=5.060
# >epoch=631, lrate=0.100, error=5.060
# >epoch=632, lrate=0.100, error=5.060
# >epoch=633, lrate=0.100, error=5.060
# >epoch=634, lrate=0.100, error=5.060
# >epoch=635, lrate=0.100, error=5.060
# >epoch=636, lrate=0.100, error=5.060
# >epoch=637, lrate=0.100, error=5.060
# >epoch=638, lrate=0.100, error=5.060
# >epoch=639, lrate=0.100, error=5.059
# >epoch=640, lrate=0.100, error=5.059
# >epoch=641, lrate=0.100, error=5.059
# >epoch=642, lrate=0.100, error=5.059
# >epoch=643, lrate=0.100, error=5.059
# >epoch=644, lrate=0.100, error=5.059
# >epoch=645, lrate=0.100, error=5.059
# >epoch=646, lrate=0.100, error=5.059
# >epoch=647, lrate=0.100, error=5.059
# >epoch=648, lrate=0.100, error=5.059
# >epoch=649, lrate=0.100, error=5.059
# >epoch=650, lrate=0.100, error=5.059
# >epoch=651, lrate=0.100, error=5.059
# >epoch=652, lrate=0.100, error=5.059
# >epoch=653, lrate=0.100, error=5.059
# >epoch=654, lrate=0.100, error=5.059
# >epoch=655, lrate=0.100, error=5.059
# >epoch=656, lrate=0.100, error=5.059
# >epoch=657, lrate=0.100, error=5.059
# >epoch=658, lrate=0.100, error=5.059
# >epoch=659, lrate=0.100, error=5.059
# >epoch=660, lrate=0.100, error=5.059
# >epoch=661, lrate=0.100, error=5.059
# >epoch=662, lrate=0.100, error=5.059
# >epoch=663, lrate=0.100, error=5.059
# >epoch=664, lrate=0.100, error=5.059
# >epoch=665, lrate=0.100, error=5.059
# >epoch=666, lrate=0.100, error=5.059
# >epoch=667, lrate=0.100, error=5.059
# >epoch=668, lrate=0.100, error=5.059
# >epoch=669, lrate=0.100, error=5.059
# >epoch=670, lrate=0.100, error=5.059
# >epoch=671, lrate=0.100, error=5.059
# >epoch=672, lrate=0.100, error=5.059
# >epoch=673, lrate=0.100, error=5.059
# >epoch=674, lrate=0.100, error=5.059
# >epoch=675, lrate=0.100, error=5.059
# >epoch=676, lrate=0.100, error=5.059
# >epoch=677, lrate=0.100, error=5.059
# >epoch=678, lrate=0.100, error=5.059
# >epoch=679, lrate=0.100, error=5.059
# >epoch=680, lrate=0.100, error=5.059
# >epoch=681, lrate=0.100, error=5.059
# >epoch=682, lrate=0.100, error=5.058
# >epoch=683, lrate=0.100, error=5.058
# >epoch=684, lrate=0.100, error=5.058
# >epoch=685, lrate=0.100, error=5.058
# >epoch=686, lrate=0.100, error=5.058
# >epoch=687, lrate=0.100, error=5.058
# >epoch=688, lrate=0.100, error=5.058
# >epoch=689, lrate=0.100, error=5.058
# >epoch=690, lrate=0.100, error=5.058
# >epoch=691, lrate=0.100, error=5.058
# >epoch=692, lrate=0.100, error=5.058
# >epoch=693, lrate=0.100, error=5.058
# >epoch=694, lrate=0.100, error=5.058
# >epoch=695, lrate=0.100, error=5.058
# >epoch=696, lrate=0.100, error=5.058
# >epoch=697, lrate=0.100, error=5.058
# >epoch=698, lrate=0.100, error=5.058
# >epoch=699, lrate=0.100, error=5.058
# >epoch=700, lrate=0.100, error=5.058
# >epoch=701, lrate=0.100, error=5.058
# >epoch=702, lrate=0.100, error=5.058
# >epoch=703, lrate=0.100, error=5.058
# >epoch=704, lrate=0.100, error=5.058
# >epoch=705, lrate=0.100, error=5.058
# >epoch=706, lrate=0.100, error=5.058
# >epoch=707, lrate=0.100, error=5.058
# >epoch=708, lrate=0.100, error=5.058
# >epoch=709, lrate=0.100, error=5.058
# >epoch=710, lrate=0.100, error=5.058
# >epoch=711, lrate=0.100, error=5.058
# >epoch=712, lrate=0.100, error=5.058
# >epoch=713, lrate=0.100, error=5.058
# >epoch=714, lrate=0.100, error=5.058
# >epoch=715, lrate=0.100, error=5.058
# >epoch=716, lrate=0.100, error=5.058
# >epoch=717, lrate=0.100, error=5.058
# >epoch=718, lrate=0.100, error=5.058
# >epoch=719, lrate=0.100, error=5.058
# >epoch=720, lrate=0.100, error=5.058
# >epoch=721, lrate=0.100, error=5.058
# >epoch=722, lrate=0.100, error=5.058
# >epoch=723, lrate=0.100, error=5.058
# >epoch=724, lrate=0.100, error=5.058
# >epoch=725, lrate=0.100, error=5.058
# >epoch=726, lrate=0.100, error=5.057
# >epoch=727, lrate=0.100, error=5.057
# >epoch=728, lrate=0.100, error=5.057
# >epoch=729, lrate=0.100, error=5.057
# >epoch=730, lrate=0.100, error=5.057
# >epoch=731, lrate=0.100, error=5.057
# >epoch=732, lrate=0.100, error=5.057
# >epoch=733, lrate=0.100, error=5.057
# >epoch=734, lrate=0.100, error=5.057
# >epoch=735, lrate=0.100, error=5.057
# >epoch=736, lrate=0.100, error=5.057
# >epoch=737, lrate=0.100, error=5.057
# >epoch=738, lrate=0.100, error=5.057
# >epoch=739, lrate=0.100, error=5.057
# >epoch=740, lrate=0.100, error=5.057
# >epoch=741, lrate=0.100, error=5.057
# >epoch=742, lrate=0.100, error=5.057
# >epoch=743, lrate=0.100, error=5.057
# >epoch=744, lrate=0.100, error=5.057
# >epoch=745, lrate=0.100, error=5.057
# >epoch=746, lrate=0.100, error=5.057
# >epoch=747, lrate=0.100, error=5.057
# >epoch=748, lrate=0.100, error=5.057
# >epoch=749, lrate=0.100, error=5.057
# >epoch=750, lrate=0.100, error=5.057
# >epoch=751, lrate=0.100, error=5.057
# >epoch=752, lrate=0.100, error=5.057
# >epoch=753, lrate=0.100, error=5.057
# >epoch=754, lrate=0.100, error=5.057
# >epoch=755, lrate=0.100, error=5.057
# >epoch=756, lrate=0.100, error=5.057
# >epoch=757, lrate=0.100, error=5.057
# >epoch=758, lrate=0.100, error=5.057
# >epoch=759, lrate=0.100, error=5.057
# >epoch=760, lrate=0.100, error=5.057
# >epoch=761, lrate=0.100, error=5.057
# >epoch=762, lrate=0.100, error=5.057
# >epoch=763, lrate=0.100, error=5.057
# >epoch=764, lrate=0.100, error=5.057
# >epoch=765, lrate=0.100, error=5.057
# >epoch=766, lrate=0.100, error=5.057
# >epoch=767, lrate=0.100, error=5.057
# >epoch=768, lrate=0.100, error=5.057
# >epoch=769, lrate=0.100, error=5.057
# >epoch=770, lrate=0.100, error=5.057
# >epoch=771, lrate=0.100, error=5.056
# >epoch=772, lrate=0.100, error=5.056
# >epoch=773, lrate=0.100, error=5.056
# >epoch=774, lrate=0.100, error=5.056
# >epoch=775, lrate=0.100, error=5.056
# >epoch=776, lrate=0.100, error=5.056
# >epoch=777, lrate=0.100, error=5.056
# >epoch=778, lrate=0.100, error=5.056
# >epoch=779, lrate=0.100, error=5.056
# >epoch=780, lrate=0.100, error=5.056
# >epoch=781, lrate=0.100, error=5.056
# >epoch=782, lrate=0.100, error=5.056
# >epoch=783, lrate=0.100, error=5.056
# >epoch=784, lrate=0.100, error=5.056
# >epoch=785, lrate=0.100, error=5.056
# >epoch=786, lrate=0.100, error=5.056
# >epoch=787, lrate=0.100, error=5.056
# >epoch=788, lrate=0.100, error=5.056
# >epoch=789, lrate=0.100, error=5.056
# >epoch=790, lrate=0.100, error=5.056
# >epoch=791, lrate=0.100, error=5.056
# >epoch=792, lrate=0.100, error=5.056
# >epoch=793, lrate=0.100, error=5.056
# >epoch=794, lrate=0.100, error=5.056
# >epoch=795, lrate=0.100, error=5.056
# >epoch=796, lrate=0.100, error=5.056
# >epoch=797, lrate=0.100, error=5.056
# >epoch=798, lrate=0.100, error=5.056
# >epoch=799, lrate=0.100, error=5.056
# >epoch=800, lrate=0.100, error=5.056
# >epoch=801, lrate=0.100, error=5.056
# >epoch=802, lrate=0.100, error=5.056
# >epoch=803, lrate=0.100, error=5.056
# >epoch=804, lrate=0.100, error=5.056
# >epoch=805, lrate=0.100, error=5.056
# >epoch=806, lrate=0.100, error=5.056
# >epoch=807, lrate=0.100, error=5.056
# >epoch=808, lrate=0.100, error=5.056
# >epoch=809, lrate=0.100, error=5.056
# >epoch=810, lrate=0.100, error=5.056
# >epoch=811, lrate=0.100, error=5.056
# >epoch=812, lrate=0.100, error=5.056
# >epoch=813, lrate=0.100, error=5.056
# >epoch=814, lrate=0.100, error=5.056
# >epoch=815, lrate=0.100, error=5.056
# >epoch=816, lrate=0.100, error=5.056
# >epoch=817, lrate=0.100, error=5.056
# >epoch=818, lrate=0.100, error=5.055
# >epoch=819, lrate=0.100, error=5.055
# >epoch=820, lrate=0.100, error=5.055
# >epoch=821, lrate=0.100, error=5.055
# >epoch=822, lrate=0.100, error=5.055
# >epoch=823, lrate=0.100, error=5.055
# >epoch=824, lrate=0.100, error=5.055
# >epoch=825, lrate=0.100, error=5.055
# >epoch=826, lrate=0.100, error=5.055
# >epoch=827, lrate=0.100, error=5.055
# >epoch=828, lrate=0.100, error=5.055
# >epoch=829, lrate=0.100, error=5.055
# >epoch=830, lrate=0.100, error=5.055
# >epoch=831, lrate=0.100, error=5.055
# >epoch=832, lrate=0.100, error=5.055
# >epoch=833, lrate=0.100, error=5.055
# >epoch=834, lrate=0.100, error=5.055
# >epoch=835, lrate=0.100, error=5.055
# >epoch=836, lrate=0.100, error=5.055
# >epoch=837, lrate=0.100, error=5.055
# >epoch=838, lrate=0.100, error=5.055
# >epoch=839, lrate=0.100, error=5.055
# >epoch=840, lrate=0.100, error=5.055
# >epoch=841, lrate=0.100, error=5.055
# >epoch=842, lrate=0.100, error=5.055
# >epoch=843, lrate=0.100, error=5.055
# >epoch=844, lrate=0.100, error=5.055
# >epoch=845, lrate=0.100, error=5.055
# >epoch=846, lrate=0.100, error=5.055
# >epoch=847, lrate=0.100, error=5.055
# >epoch=848, lrate=0.100, error=5.055
# >epoch=849, lrate=0.100, error=5.055
# >epoch=850, lrate=0.100, error=5.055
# >epoch=851, lrate=0.100, error=5.055
# >epoch=852, lrate=0.100, error=5.055
# >epoch=853, lrate=0.100, error=5.055
# >epoch=854, lrate=0.100, error=5.055
# >epoch=855, lrate=0.100, error=5.055
# >epoch=856, lrate=0.100, error=5.055
# >epoch=857, lrate=0.100, error=5.055
# >epoch=858, lrate=0.100, error=5.055
# >epoch=859, lrate=0.100, error=5.055
# >epoch=860, lrate=0.100, error=5.055
# >epoch=861, lrate=0.100, error=5.055
# >epoch=862, lrate=0.100, error=5.055
# >epoch=863, lrate=0.100, error=5.055
# >epoch=864, lrate=0.100, error=5.055
# >epoch=865, lrate=0.100, error=5.055
# >epoch=866, lrate=0.100, error=5.055
# >epoch=867, lrate=0.100, error=5.055
# >epoch=868, lrate=0.100, error=5.054
# >epoch=869, lrate=0.100, error=5.054
# >epoch=870, lrate=0.100, error=5.054
# >epoch=871, lrate=0.100, error=5.054
# >epoch=872, lrate=0.100, error=5.054
# >epoch=873, lrate=0.100, error=5.054
# >epoch=874, lrate=0.100, error=5.054
# >epoch=875, lrate=0.100, error=5.054
# >epoch=876, lrate=0.100, error=5.054
# >epoch=877, lrate=0.100, error=5.054
# >epoch=878, lrate=0.100, error=5.054
# >epoch=879, lrate=0.100, error=5.054
# >epoch=880, lrate=0.100, error=5.054
# >epoch=881, lrate=0.100, error=5.054
# >epoch=882, lrate=0.100, error=5.054
# >epoch=883, lrate=0.100, error=5.054
# >epoch=884, lrate=0.100, error=5.054
# >epoch=885, lrate=0.100, error=5.054
# >epoch=886, lrate=0.100, error=5.054
# >epoch=887, lrate=0.100, error=5.054
# >epoch=888, lrate=0.100, error=5.054
# >epoch=889, lrate=0.100, error=5.054
# >epoch=890, lrate=0.100, error=5.054
# >epoch=891, lrate=0.100, error=5.054
# >epoch=892, lrate=0.100, error=5.054
# >epoch=893, lrate=0.100, error=5.054
# >epoch=894, lrate=0.100, error=5.054
# >epoch=895, lrate=0.100, error=5.054
# >epoch=896, lrate=0.100, error=5.054
# >epoch=897, lrate=0.100, error=5.054
# >epoch=898, lrate=0.100, error=5.054
# >epoch=899, lrate=0.100, error=5.054
# >epoch=900, lrate=0.100, error=5.054
# >epoch=901, lrate=0.100, error=5.054
# >epoch=902, lrate=0.100, error=5.054
# >epoch=903, lrate=0.100, error=5.054
# >epoch=904, lrate=0.100, error=5.054
# >epoch=905, lrate=0.100, error=5.054
# >epoch=906, lrate=0.100, error=5.054
# >epoch=907, lrate=0.100, error=5.054
# >epoch=908, lrate=0.100, error=5.054
# >epoch=909, lrate=0.100, error=5.054
# >epoch=910, lrate=0.100, error=5.054
# >epoch=911, lrate=0.100, error=5.054
# >epoch=912, lrate=0.100, error=5.054
# >epoch=913, lrate=0.100, error=5.054
# >epoch=914, lrate=0.100, error=5.054
# >epoch=915, lrate=0.100, error=5.054
# >epoch=916, lrate=0.100, error=5.054
# >epoch=917, lrate=0.100, error=5.054
# >epoch=918, lrate=0.100, error=5.054
# >epoch=919, lrate=0.100, error=5.053
# >epoch=920, lrate=0.100, error=5.053
# >epoch=921, lrate=0.100, error=5.053
# >epoch=922, lrate=0.100, error=5.053
# >epoch=923, lrate=0.100, error=5.053
# >epoch=924, lrate=0.100, error=5.053
# >epoch=925, lrate=0.100, error=5.053
# >epoch=926, lrate=0.100, error=5.053
# >epoch=927, lrate=0.100, error=5.053
# >epoch=928, lrate=0.100, error=5.053
# >epoch=929, lrate=0.100, error=5.053
# >epoch=930, lrate=0.100, error=5.053
# >epoch=931, lrate=0.100, error=5.053
# >epoch=932, lrate=0.100, error=5.053
# >epoch=933, lrate=0.100, error=5.053
# >epoch=934, lrate=0.100, error=5.053
# >epoch=935, lrate=0.100, error=5.053
# >epoch=936, lrate=0.100, error=5.053
# >epoch=937, lrate=0.100, error=5.053
# >epoch=938, lrate=0.100, error=5.053
# >epoch=939, lrate=0.100, error=5.053
# >epoch=940, lrate=0.100, error=5.053
# >epoch=941, lrate=0.100, error=5.053
# >epoch=942, lrate=0.100, error=5.053
# >epoch=943, lrate=0.100, error=5.053
# >epoch=944, lrate=0.100, error=5.053
# >epoch=945, lrate=0.100, error=5.053
# >epoch=946, lrate=0.100, error=5.053
# >epoch=947, lrate=0.100, error=5.053
# >epoch=948, lrate=0.100, error=5.053
# >epoch=949, lrate=0.100, error=5.053
# >epoch=950, lrate=0.100, error=5.053
# >epoch=951, lrate=0.100, error=5.053
# >epoch=952, lrate=0.100, error=5.053
# >epoch=953, lrate=0.100, error=5.053
# >epoch=954, lrate=0.100, error=5.053
# >epoch=955, lrate=0.100, error=5.053
# >epoch=956, lrate=0.100, error=5.053
# >epoch=957, lrate=0.100, error=5.053
# >epoch=958, lrate=0.100, error=5.053
# >epoch=959, lrate=0.100, error=5.053
# >epoch=960, lrate=0.100, error=5.053
# >epoch=961, lrate=0.100, error=5.053
# >epoch=962, lrate=0.100, error=5.053
# >epoch=963, lrate=0.100, error=5.053
# >epoch=964, lrate=0.100, error=5.053
# >epoch=965, lrate=0.100, error=5.053
# >epoch=966, lrate=0.100, error=5.053
# >epoch=967, lrate=0.100, error=5.053
# >epoch=968, lrate=0.100, error=5.053
# >epoch=969, lrate=0.100, error=5.053
# >epoch=970, lrate=0.100, error=5.053
# >epoch=971, lrate=0.100, error=5.053
# >epoch=972, lrate=0.100, error=5.053
# >epoch=973, lrate=0.100, error=5.052
# >epoch=974, lrate=0.100, error=5.052
# >epoch=975, lrate=0.100, error=5.052
# >epoch=976, lrate=0.100, error=5.052
# >epoch=977, lrate=0.100, error=5.052
# >epoch=978, lrate=0.100, error=5.052
# >epoch=979, lrate=0.100, error=5.052
# >epoch=980, lrate=0.100, error=5.052
# >epoch=981, lrate=0.100, error=5.052
# >epoch=982, lrate=0.100, error=5.052
# >epoch=983, lrate=0.100, error=5.052
# >epoch=984, lrate=0.100, error=5.052
# >epoch=985, lrate=0.100, error=5.052
# >epoch=986, lrate=0.100, error=5.052
# >epoch=987, lrate=0.100, error=5.052
# >epoch=988, lrate=0.100, error=5.052
# >epoch=989, lrate=0.100, error=5.052
# >epoch=990, lrate=0.100, error=5.052
# >epoch=991, lrate=0.100, error=5.052
# >epoch=992, lrate=0.100, error=5.052
# >epoch=993, lrate=0.100, error=5.052
# >epoch=994, lrate=0.100, error=5.052
# >epoch=995, lrate=0.100, error=5.052
# >epoch=996, lrate=0.100, error=5.052
# >epoch=997, lrate=0.100, error=5.052
# >epoch=998, lrate=0.100, error=5.052
# >epoch=999, lrate=0.100, error=5.052
# >epoch=1000, lrate=0.100, error=5.052
# >epoch=1001, lrate=0.100, error=5.052
# >epoch=1002, lrate=0.100, error=5.052
# >epoch=1003, lrate=0.100, error=5.052
# >epoch=1004, lrate=0.100, error=5.052
# >epoch=1005, lrate=0.100, error=5.052
# >epoch=1006, lrate=0.100, error=5.052
# >epoch=1007, lrate=0.100, error=5.052
# >epoch=1008, lrate=0.100, error=5.052
# >epoch=1009, lrate=0.100, error=5.052
# >epoch=1010, lrate=0.100, error=5.052
# >epoch=1011, lrate=0.100, error=5.052
# >epoch=1012, lrate=0.100, error=5.052
# >epoch=1013, lrate=0.100, error=5.052
# >epoch=1014, lrate=0.100, error=5.052
# >epoch=1015, lrate=0.100, error=5.052
# >epoch=1016, lrate=0.100, error=5.052
# >epoch=1017, lrate=0.100, error=5.052
# >epoch=1018, lrate=0.100, error=5.052
# >epoch=1019, lrate=0.100, error=5.052
# >epoch=1020, lrate=0.100, error=5.052
# >epoch=1021, lrate=0.100, error=5.052
# >epoch=1022, lrate=0.100, error=5.052
# >epoch=1023, lrate=0.100, error=5.052
# >epoch=1024, lrate=0.100, error=5.052
# >epoch=1025, lrate=0.100, error=5.052
# >epoch=1026, lrate=0.100, error=5.052
# >epoch=1027, lrate=0.100, error=5.052
# >epoch=1028, lrate=0.100, error=5.052
# >epoch=1029, lrate=0.100, error=5.052
# >epoch=1030, lrate=0.100, error=5.051
# >epoch=1031, lrate=0.100, error=5.051
# >epoch=1032, lrate=0.100, error=5.051
# >epoch=1033, lrate=0.100, error=5.051
# >epoch=1034, lrate=0.100, error=5.051
# >epoch=1035, lrate=0.100, error=5.051
# >epoch=1036, lrate=0.100, error=5.051
# >epoch=1037, lrate=0.100, error=5.051
# >epoch=1038, lrate=0.100, error=5.051
# >epoch=1039, lrate=0.100, error=5.051
# >epoch=1040, lrate=0.100, error=5.051
# >epoch=1041, lrate=0.100, error=5.051
# >epoch=1042, lrate=0.100, error=5.051
# >epoch=1043, lrate=0.100, error=5.051
# >epoch=1044, lrate=0.100, error=5.051
# >epoch=1045, lrate=0.100, error=5.051
# >epoch=1046, lrate=0.100, error=5.051
# >epoch=1047, lrate=0.100, error=5.051
# >epoch=1048, lrate=0.100, error=5.051
# >epoch=1049, lrate=0.100, error=5.051
# >epoch=1050, lrate=0.100, error=5.051
# >epoch=1051, lrate=0.100, error=5.051
# >epoch=1052, lrate=0.100, error=5.051
# >epoch=1053, lrate=0.100, error=5.051
# >epoch=1054, lrate=0.100, error=5.051
# >epoch=1055, lrate=0.100, error=5.051
# >epoch=1056, lrate=0.100, error=5.051
# >epoch=1057, lrate=0.100, error=5.051
# >epoch=1058, lrate=0.100, error=5.051
# >epoch=1059, lrate=0.100, error=5.051
# >epoch=1060, lrate=0.100, error=5.051
# >epoch=1061, lrate=0.100, error=5.051
# >epoch=1062, lrate=0.100, error=5.051
# >epoch=1063, lrate=0.100, error=5.051
# >epoch=1064, lrate=0.100, error=5.051
# >epoch=1065, lrate=0.100, error=5.051
# >epoch=1066, lrate=0.100, error=5.051
# >epoch=1067, lrate=0.100, error=5.051
# >epoch=1068, lrate=0.100, error=5.051
# >epoch=1069, lrate=0.100, error=5.051
# >epoch=1070, lrate=0.100, error=5.051
# >epoch=1071, lrate=0.100, error=5.051
# >epoch=1072, lrate=0.100, error=5.051
# >epoch=1073, lrate=0.100, error=5.051
# >epoch=1074, lrate=0.100, error=5.051
# >epoch=1075, lrate=0.100, error=5.051
# >epoch=1076, lrate=0.100, error=5.051
# >epoch=1077, lrate=0.100, error=5.051
# >epoch=1078, lrate=0.100, error=5.051
# >epoch=1079, lrate=0.100, error=5.051
# >epoch=1080, lrate=0.100, error=5.051
# >epoch=1081, lrate=0.100, error=5.051
# >epoch=1082, lrate=0.100, error=5.051
# >epoch=1083, lrate=0.100, error=5.051
# >epoch=1084, lrate=0.100, error=5.051
# >epoch=1085, lrate=0.100, error=5.051
# >epoch=1086, lrate=0.100, error=5.051
# >epoch=1087, lrate=0.100, error=5.051
# >epoch=1088, lrate=0.100, error=5.051
# >epoch=1089, lrate=0.100, error=5.051
# >epoch=1090, lrate=0.100, error=5.050
# >epoch=1091, lrate=0.100, error=5.050
# >epoch=1092, lrate=0.100, error=5.050
# >epoch=1093, lrate=0.100, error=5.050
# >epoch=1094, lrate=0.100, error=5.050
# >epoch=1095, lrate=0.100, error=5.050
# >epoch=1096, lrate=0.100, error=5.050
# >epoch=1097, lrate=0.100, error=5.050
# >epoch=1098, lrate=0.100, error=5.050
# >epoch=1099, lrate=0.100, error=5.050
# >epoch=1100, lrate=0.100, error=5.050
# >epoch=1101, lrate=0.100, error=5.050
# >epoch=1102, lrate=0.100, error=5.050
# >epoch=1103, lrate=0.100, error=5.050
# >epoch=1104, lrate=0.100, error=5.050
# >epoch=1105, lrate=0.100, error=5.050
# >epoch=1106, lrate=0.100, error=5.050
# >epoch=1107, lrate=0.100, error=5.050
# >epoch=1108, lrate=0.100, error=5.050
# >epoch=1109, lrate=0.100, error=5.050
# >epoch=1110, lrate=0.100, error=5.050
# >epoch=1111, lrate=0.100, error=5.050
# >epoch=1112, lrate=0.100, error=5.050
# >epoch=1113, lrate=0.100, error=5.050
# >epoch=1114, lrate=0.100, error=5.050
# >epoch=1115, lrate=0.100, error=5.050
# >epoch=1116, lrate=0.100, error=5.050
# >epoch=1117, lrate=0.100, error=5.050
# >epoch=1118, lrate=0.100, error=5.050
# >epoch=1119, lrate=0.100, error=5.050
# >epoch=1120, lrate=0.100, error=5.050
# >epoch=1121, lrate=0.100, error=5.050
# >epoch=1122, lrate=0.100, error=5.050
# >epoch=1123, lrate=0.100, error=5.050
# >epoch=1124, lrate=0.100, error=5.050
# >epoch=1125, lrate=0.100, error=5.050
# >epoch=1126, lrate=0.100, error=5.050
# >epoch=1127, lrate=0.100, error=5.050
# >epoch=1128, lrate=0.100, error=5.050
# >epoch=1129, lrate=0.100, error=5.050
# >epoch=1130, lrate=0.100, error=5.050
# >epoch=1131, lrate=0.100, error=5.050
# >epoch=1132, lrate=0.100, error=5.050
# >epoch=1133, lrate=0.100, error=5.050
# >epoch=1134, lrate=0.100, error=5.050
# >epoch=1135, lrate=0.100, error=5.050
# >epoch=1136, lrate=0.100, error=5.050
# >epoch=1137, lrate=0.100, error=5.050
# >epoch=1138, lrate=0.100, error=5.050
# >epoch=1139, lrate=0.100, error=5.050
# >epoch=1140, lrate=0.100, error=5.050
# >epoch=1141, lrate=0.100, error=5.050
# >epoch=1142, lrate=0.100, error=5.050
# >epoch=1143, lrate=0.100, error=5.050
# >epoch=1144, lrate=0.100, error=5.050
# >epoch=1145, lrate=0.100, error=5.050
# >epoch=1146, lrate=0.100, error=5.050
# >epoch=1147, lrate=0.100, error=5.050
# >epoch=1148, lrate=0.100, error=5.050
# >epoch=1149, lrate=0.100, error=5.050
# >epoch=1150, lrate=0.100, error=5.050
# >epoch=1151, lrate=0.100, error=5.050
# >epoch=1152, lrate=0.100, error=5.050
# >epoch=1153, lrate=0.100, error=5.049
# >epoch=1154, lrate=0.100, error=5.049
# >epoch=1155, lrate=0.100, error=5.049
# >epoch=1156, lrate=0.100, error=5.049
# >epoch=1157, lrate=0.100, error=5.049
# >epoch=1158, lrate=0.100, error=5.049
# >epoch=1159, lrate=0.100, error=5.049
# >epoch=1160, lrate=0.100, error=5.049
# >epoch=1161, lrate=0.100, error=5.049
# >epoch=1162, lrate=0.100, error=5.049
# >epoch=1163, lrate=0.100, error=5.049
# >epoch=1164, lrate=0.100, error=5.049
# >epoch=1165, lrate=0.100, error=5.049
# >epoch=1166, lrate=0.100, error=5.049
# >epoch=1167, lrate=0.100, error=5.049
# >epoch=1168, lrate=0.100, error=5.049
# >epoch=1169, lrate=0.100, error=5.049
# >epoch=1170, lrate=0.100, error=5.049
# >epoch=1171, lrate=0.100, error=5.049
# >epoch=1172, lrate=0.100, error=5.049
# >epoch=1173, lrate=0.100, error=5.049
# >epoch=1174, lrate=0.100, error=5.049
# >epoch=1175, lrate=0.100, error=5.049
# >epoch=1176, lrate=0.100, error=5.049
# >epoch=1177, lrate=0.100, error=5.049
# >epoch=1178, lrate=0.100, error=5.049
# >epoch=1179, lrate=0.100, error=5.049
# >epoch=1180, lrate=0.100, error=5.049
# >epoch=1181, lrate=0.100, error=5.049
# >epoch=1182, lrate=0.100, error=5.049
# >epoch=1183, lrate=0.100, error=5.049
# >epoch=1184, lrate=0.100, error=5.049
# >epoch=1185, lrate=0.100, error=5.049
# >epoch=1186, lrate=0.100, error=5.049
# >epoch=1187, lrate=0.100, error=5.049
# >epoch=1188, lrate=0.100, error=5.049
# >epoch=1189, lrate=0.100, error=5.049
# >epoch=1190, lrate=0.100, error=5.049
# >epoch=1191, lrate=0.100, error=5.049
# >epoch=1192, lrate=0.100, error=5.049
# >epoch=1193, lrate=0.100, error=5.049
# >epoch=1194, lrate=0.100, error=5.049
# >epoch=1195, lrate=0.100, error=5.049
# >epoch=1196, lrate=0.100, error=5.049
# >epoch=1197, lrate=0.100, error=5.049
# >epoch=1198, lrate=0.100, error=5.049
# >epoch=1199, lrate=0.100, error=5.049
# >epoch=1200, lrate=0.100, error=5.049
# >epoch=1201, lrate=0.100, error=5.049
# >epoch=1202, lrate=0.100, error=5.049
# >epoch=1203, lrate=0.100, error=5.049
# >epoch=1204, lrate=0.100, error=5.049
# >epoch=1205, lrate=0.100, error=5.049
# >epoch=1206, lrate=0.100, error=5.049
# >epoch=1207, lrate=0.100, error=5.049
# >epoch=1208, lrate=0.100, error=5.049
# >epoch=1209, lrate=0.100, error=5.049
# >epoch=1210, lrate=0.100, error=5.049
# >epoch=1211, lrate=0.100, error=5.049
# >epoch=1212, lrate=0.100, error=5.049
# >epoch=1213, lrate=0.100, error=5.049
# >epoch=1214, lrate=0.100, error=5.049
# >epoch=1215, lrate=0.100, error=5.049
# >epoch=1216, lrate=0.100, error=5.049
# >epoch=1217, lrate=0.100, error=5.049
# >epoch=1218, lrate=0.100, error=5.049
# >epoch=1219, lrate=0.100, error=5.049
# >epoch=1220, lrate=0.100, error=5.049
# >epoch=1221, lrate=0.100, error=5.048
# >epoch=1222, lrate=0.100, error=5.048
# >epoch=1223, lrate=0.100, error=5.048
# >epoch=1224, lrate=0.100, error=5.048
# >epoch=1225, lrate=0.100, error=5.048
# >epoch=1226, lrate=0.100, error=5.048
# >epoch=1227, lrate=0.100, error=5.048
# >epoch=1228, lrate=0.100, error=5.048
# >epoch=1229, lrate=0.100, error=5.048
# >epoch=1230, lrate=0.100, error=5.048
# >epoch=1231, lrate=0.100, error=5.048
# >epoch=1232, lrate=0.100, error=5.048
# >epoch=1233, lrate=0.100, error=5.048
# >epoch=1234, lrate=0.100, error=5.048
# >epoch=1235, lrate=0.100, error=5.048
# >epoch=1236, lrate=0.100, error=5.048
# >epoch=1237, lrate=0.100, error=5.048
# >epoch=1238, lrate=0.100, error=5.048
# >epoch=1239, lrate=0.100, error=5.048
# >epoch=1240, lrate=0.100, error=5.048
# >epoch=1241, lrate=0.100, error=5.048
# >epoch=1242, lrate=0.100, error=5.048
# >epoch=1243, lrate=0.100, error=5.048
# >epoch=1244, lrate=0.100, error=5.048
# >epoch=1245, lrate=0.100, error=5.048
# >epoch=1246, lrate=0.100, error=5.048
# >epoch=1247, lrate=0.100, error=5.048
# >epoch=1248, lrate=0.100, error=5.048
# >epoch=1249, lrate=0.100, error=5.048
# >epoch=1250, lrate=0.100, error=5.048
# >epoch=1251, lrate=0.100, error=5.048
# >epoch=1252, lrate=0.100, error=5.048
# >epoch=1253, lrate=0.100, error=5.048
# >epoch=1254, lrate=0.100, error=5.048
# >epoch=1255, lrate=0.100, error=5.048
# >epoch=1256, lrate=0.100, error=5.048
# >epoch=1257, lrate=0.100, error=5.048
# >epoch=1258, lrate=0.100, error=5.048
# >epoch=1259, lrate=0.100, error=5.048
# >epoch=1260, lrate=0.100, error=5.048
# >epoch=1261, lrate=0.100, error=5.048
# >epoch=1262, lrate=0.100, error=5.048
# >epoch=1263, lrate=0.100, error=5.048
# >epoch=1264, lrate=0.100, error=5.048
# >epoch=1265, lrate=0.100, error=5.048
# >epoch=1266, lrate=0.100, error=5.048
# >epoch=1267, lrate=0.100, error=5.048
# >epoch=1268, lrate=0.100, error=5.048
# >epoch=1269, lrate=0.100, error=5.048
# >epoch=1270, lrate=0.100, error=5.048
# >epoch=1271, lrate=0.100, error=5.048
# >epoch=1272, lrate=0.100, error=5.048
# >epoch=1273, lrate=0.100, error=5.048
# >epoch=1274, lrate=0.100, error=5.048
# >epoch=1275, lrate=0.100, error=5.048
# >epoch=1276, lrate=0.100, error=5.048
# >epoch=1277, lrate=0.100, error=5.048
# >epoch=1278, lrate=0.100, error=5.048
# >epoch=1279, lrate=0.100, error=5.048
# >epoch=1280, lrate=0.100, error=5.048
# >epoch=1281, lrate=0.100, error=5.048
# >epoch=1282, lrate=0.100, error=5.048
# >epoch=1283, lrate=0.100, error=5.048
# >epoch=1284, lrate=0.100, error=5.048
# >epoch=1285, lrate=0.100, error=5.048
# >epoch=1286, lrate=0.100, error=5.048
# >epoch=1287, lrate=0.100, error=5.048
# >epoch=1288, lrate=0.100, error=5.048
# >epoch=1289, lrate=0.100, error=5.048
# >epoch=1290, lrate=0.100, error=5.048
# ...
# >epoch=4579, lrate=0.100, error=5.034
# >epoch=4580, lrate=0.100, error=5.034
# >epoch=4581, lrate=0.100, error=5.034
# >epoch=4582, lrate=0.100, error=5.034
# >epoch=4583, lrate=0.100, error=5.034
# >epoch=4584, lrate=0.100, error=5.034
# >epoch=4585, lrate=0.100, error=5.034
# >epoch=4586, lrate=0.100, error=5.034
# >epoch=4587, lrate=0.100, error=5.034
# >epoch=4588, lrate=0.100, error=5.034
# >epoch=4589, lrate=0.100, error=5.034
# >epoch=4590, lrate=0.100, error=5.034
# >epoch=4591, lrate=0.100, error=5.034
# >epoch=4592, lrate=0.100, error=5.034
# >epoch=4593, lrate=0.100, error=5.034
# >epoch=4594, lrate=0.100, error=5.034
# >epoch=4595, lrate=0.100, error=5.034
# >epoch=4596, lrate=0.100, error=5.034
# >epoch=4597, lrate=0.100, error=5.034
# >epoch=4598, lrate=0.100, error=5.034
# >epoch=4599, lrate=0.100, error=5.034
# >epoch=4600, lrate=0.100, error=5.034
# >epoch=4601, lrate=0.100, error=5.034
# >epoch=4602, lrate=0.100, error=5.034
# >epoch=4603, lrate=0.100, error=5.034
# >epoch=4604, lrate=0.100, error=5.034
# >epoch=4605, lrate=0.100, error=5.034
# >epoch=4606, lrate=0.100, error=5.034
# >epoch=4607, lrate=0.100, error=5.034
# >epoch=4608, lrate=0.100, error=5.034
# >epoch=4609, lrate=0.100, error=5.034
# >epoch=4610, lrate=0.100, error=5.034
# >epoch=4611, lrate=0.100, error=5.034
# >epoch=4612, lrate=0.100, error=5.034
# >epoch=4613, lrate=0.100, error=5.034
# >epoch=4614, lrate=0.100, error=5.034
# >epoch=4615, lrate=0.100, error=5.034
# >epoch=4616, lrate=0.100, error=5.034
# >epoch=4617, lrate=0.100, error=5.034
# >epoch=4618, lrate=0.100, error=5.034
# >epoch=4619, lrate=0.100, error=5.034
# >epoch=4620, lrate=0.100, error=5.034
# >epoch=4621, lrate=0.100, error=5.034
# >epoch=4622, lrate=0.100, error=5.034
# >epoch=4623, lrate=0.100, error=5.034
# >epoch=4624, lrate=0.100, error=5.034
# >epoch=4625, lrate=0.100, error=5.034
# >epoch=4626, lrate=0.100, error=5.034
# >epoch=4627, lrate=0.100, error=5.034
# >epoch=4628, lrate=0.100, error=5.034
# >epoch=4629, lrate=0.100, error=5.034
# >epoch=4630, lrate=0.100, error=5.034
# >epoch=4631, lrate=0.100, error=5.034
# >epoch=4632, lrate=0.100, error=5.034
# >epoch=4633, lrate=0.100, error=5.034
# >epoch=4634, lrate=0.100, error=5.034
# >epoch=4635, lrate=0.100, error=5.034
# >epoch=4636, lrate=0.100, error=5.034
# >epoch=4637, lrate=0.100, error=5.034
# >epoch=4638, lrate=0.100, error=5.034
# >epoch=4639, lrate=0.100, error=5.034
# >epoch=4640, lrate=0.100, error=5.034
# >epoch=4641, lrate=0.100, error=5.034
# >epoch=4642, lrate=0.100, error=5.034
# >epoch=4643, lrate=0.100, error=5.034
# >epoch=4644, lrate=0.100, error=5.034
# >epoch=4645, lrate=0.100, error=5.034
# >epoch=4646, lrate=0.100, error=5.034
# >epoch=4647, lrate=0.100, error=5.034
# >epoch=4648, lrate=0.100, error=5.034
# >epoch=4649, lrate=0.100, error=5.034
# >epoch=4650, lrate=0.100, error=5.034
# >epoch=4651, lrate=0.100, error=5.034
# >epoch=4652, lrate=0.100, error=5.034
# >epoch=4653, lrate=0.100, error=5.034
# >epoch=4654, lrate=0.100, error=5.034
# >epoch=4655, lrate=0.100, error=5.034
# >epoch=4656, lrate=0.100, error=5.034
# >epoch=4657, lrate=0.100, error=5.034
# >epoch=4658, lrate=0.100, error=5.034
# >epoch=4659, lrate=0.100, error=5.034
# >epoch=4660, lrate=0.100, error=5.034
# >epoch=4661, lrate=0.100, error=5.034
# >epoch=4662, lrate=0.100, error=5.034
# >epoch=4663, lrate=0.100, error=5.034
# >epoch=4664, lrate=0.100, error=5.034
# >epoch=4665, lrate=0.100, error=5.034
# >epoch=4666, lrate=0.100, error=5.034
# >epoch=4667, lrate=0.100, error=5.034
# >epoch=4668, lrate=0.100, error=5.034
# >epoch=4669, lrate=0.100, error=5.034
# >epoch=4670, lrate=0.100, error=5.034
# >epoch=4671, lrate=0.100, error=5.034
# >epoch=4672, lrate=0.100, error=5.034
# >epoch=4673, lrate=0.100, error=5.034
# >epoch=4674, lrate=0.100, error=5.034
# >epoch=4675, lrate=0.100, error=5.034
# >epoch=4676, lrate=0.100, error=5.034
# >epoch=4677, lrate=0.100, error=5.034
# >epoch=4678, lrate=0.100, error=5.034
# >epoch=4679, lrate=0.100, error=5.034
# >epoch=4680, lrate=0.100, error=5.034
# >epoch=4681, lrate=0.100, error=5.034
# >epoch=4682, lrate=0.100, error=5.034
# >epoch=4683, lrate=0.100, error=5.034
# >epoch=4684, lrate=0.100, error=5.034
# >epoch=4685, lrate=0.100, error=5.034
# >epoch=4686, lrate=0.100, error=5.034
# >epoch=4687, lrate=0.100, error=5.034
# >epoch=4688, lrate=0.100, error=5.034
# >epoch=4689, lrate=0.100, error=5.034
# >epoch=4690, lrate=0.100, error=5.034
# >epoch=4691, lrate=0.100, error=5.034
# >epoch=4692, lrate=0.100, error=5.034
# >epoch=4693, lrate=0.100, error=5.034
# >epoch=4694, lrate=0.100, error=5.034
# >epoch=4695, lrate=0.100, error=5.034
# >epoch=4696, lrate=0.100, error=5.034
# >epoch=4697, lrate=0.100, error=5.034
# >epoch=4698, lrate=0.100, error=5.034
# >epoch=4699, lrate=0.100, error=5.034
# >epoch=4700, lrate=0.100, error=5.034
# >epoch=4701, lrate=0.100, error=5.034
# >epoch=4702, lrate=0.100, error=5.034
# >epoch=4703, lrate=0.100, error=5.034
# >epoch=4704, lrate=0.100, error=5.034
# >epoch=4705, lrate=0.100, error=5.034
# >epoch=4706, lrate=0.100, error=5.034
# >epoch=4707, lrate=0.100, error=5.034
# >epoch=4708, lrate=0.100, error=5.034
# >epoch=4709, lrate=0.100, error=5.034
# >epoch=4710, lrate=0.100, error=5.034
# >epoch=4711, lrate=0.100, error=5.034
# >epoch=4712, lrate=0.100, error=5.034
# >epoch=4713, lrate=0.100, error=5.034
# >epoch=4714, lrate=0.100, error=5.034
# >epoch=4715, lrate=0.100, error=5.034
# >epoch=4716, lrate=0.100, error=5.034
# >epoch=4717, lrate=0.100, error=5.034
# >epoch=4718, lrate=0.100, error=5.034
# >epoch=4719, lrate=0.100, error=5.034
# >epoch=4720, lrate=0.100, error=5.034
# >epoch=4721, lrate=0.100, error=5.034
# >epoch=4722, lrate=0.100, error=5.034
# >epoch=4723, lrate=0.100, error=5.034
# >epoch=4724, lrate=0.100, error=5.034
# >epoch=4725, lrate=0.100, error=5.034
# >epoch=4726, lrate=0.100, error=5.034
# >epoch=4727, lrate=0.100, error=5.034
# >epoch=4728, lrate=0.100, error=5.034
# >epoch=4729, lrate=0.100, error=5.034
# >epoch=4730, lrate=0.100, error=5.034
# >epoch=4731, lrate=0.100, error=5.034
# >epoch=4732, lrate=0.100, error=5.034
# >epoch=4733, lrate=0.100, error=5.034
# >epoch=4734, lrate=0.100, error=5.034
# >epoch=4735, lrate=0.100, error=5.034
# >epoch=4736, lrate=0.100, error=5.034
# >epoch=4737, lrate=0.100, error=5.034
# >epoch=4738, lrate=0.100, error=5.034
# >epoch=4739, lrate=0.100, error=5.034
# >epoch=4740, lrate=0.100, error=5.034
# >epoch=4741, lrate=0.100, error=5.034
# >epoch=4742, lrate=0.100, error=5.034
# >epoch=4743, lrate=0.100, error=5.034
# >epoch=4744, lrate=0.100, error=5.034
# >epoch=4745, lrate=0.100, error=5.034
# >epoch=4746, lrate=0.100, error=5.034
# >epoch=4747, lrate=0.100, error=5.034
# >epoch=4748, lrate=0.100, error=5.034
# >epoch=4749, lrate=0.100, error=5.034
# >epoch=4750, lrate=0.100, error=5.034
# >epoch=4751, lrate=0.100, error=5.034
# >epoch=4752, lrate=0.100, error=5.034
# >epoch=4753, lrate=0.100, error=5.034
# >epoch=4754, lrate=0.100, error=5.034
# >epoch=4755, lrate=0.100, error=5.034
# >epoch=4756, lrate=0.100, error=5.034
# >epoch=4757, lrate=0.100, error=5.034
# >epoch=4758, lrate=0.100, error=5.034
# >epoch=4759, lrate=0.100, error=5.034
# >epoch=4760, lrate=0.100, error=5.034
# >epoch=4761, lrate=0.100, error=5.034
# >epoch=4762, lrate=0.100, error=5.034
# >epoch=4763, lrate=0.100, error=5.034
# >epoch=4764, lrate=0.100, error=5.034
# >epoch=4765, lrate=0.100, error=5.034
# >epoch=4766, lrate=0.100, error=5.034
# >epoch=4767, lrate=0.100, error=5.034
# >epoch=4768, lrate=0.100, error=5.034
# >epoch=4769, lrate=0.100, error=5.034
# >epoch=4770, lrate=0.100, error=5.034
# >epoch=4771, lrate=0.100, error=5.034
# >epoch=4772, lrate=0.100, error=5.034
# >epoch=4773, lrate=0.100, error=5.034
# >epoch=4774, lrate=0.100, error=5.034
# >epoch=4775, lrate=0.100, error=5.034
# >epoch=4776, lrate=0.100, error=5.034
# >epoch=4777, lrate=0.100, error=5.034
# >epoch=4778, lrate=0.100, error=5.034
# >epoch=4779, lrate=0.100, error=5.034
# >epoch=4780, lrate=0.100, error=5.034
# >epoch=4781, lrate=0.100, error=5.034
# >epoch=4782, lrate=0.100, error=5.034
# >epoch=4783, lrate=0.100, error=5.034
# >epoch=4784, lrate=0.100, error=5.034
# >epoch=4785, lrate=0.100, error=5.034
# >epoch=4786, lrate=0.100, error=5.034
# >epoch=4787, lrate=0.100, error=5.034
# >epoch=4788, lrate=0.100, error=5.034
# >epoch=4789, lrate=0.100, error=5.034
# >epoch=4790, lrate=0.100, error=5.034
# >epoch=4791, lrate=0.100, error=5.034
# >epoch=4792, lrate=0.100, error=5.034
# >epoch=4793, lrate=0.100, error=5.034
# >epoch=4794, lrate=0.100, error=5.034
# >epoch=4795, lrate=0.100, error=5.034
# >epoch=4796, lrate=0.100, error=5.034
# >epoch=4797, lrate=0.100, error=5.034
# >epoch=4798, lrate=0.100, error=5.034
# >epoch=4799, lrate=0.100, error=5.034
# >epoch=4800, lrate=0.100, error=5.034
# >epoch=4801, lrate=0.100, error=5.034
# >epoch=4802, lrate=0.100, error=5.034
# >epoch=4803, lrate=0.100, error=5.034
# >epoch=4804, lrate=0.100, error=5.034
# >epoch=4805, lrate=0.100, error=5.034
# >epoch=4806, lrate=0.100, error=5.034
# >epoch=4807, lrate=0.100, error=5.034
# >epoch=4808, lrate=0.100, error=5.034
# >epoch=4809, lrate=0.100, error=5.034
# >epoch=4810, lrate=0.100, error=5.034
# >epoch=4811, lrate=0.100, error=5.034
# >epoch=4812, lrate=0.100, error=5.034
# >epoch=4813, lrate=0.100, error=5.034
# >epoch=4814, lrate=0.100, error=5.034
# >epoch=4815, lrate=0.100, error=5.034
# >epoch=4816, lrate=0.100, error=5.034
# >epoch=4817, lrate=0.100, error=5.034
# >epoch=4818, lrate=0.100, error=5.034
# >epoch=4819, lrate=0.100, error=5.034
# >epoch=4820, lrate=0.100, error=5.034
# >epoch=4821, lrate=0.100, error=5.034
# >epoch=4822, lrate=0.100, error=5.034
# >epoch=4823, lrate=0.100, error=5.034
# >epoch=4824, lrate=0.100, error=5.034
# >epoch=4825, lrate=0.100, error=5.034
# >epoch=4826, lrate=0.100, error=5.034
# >epoch=4827, lrate=0.100, error=5.034
# >epoch=4828, lrate=0.100, error=5.034
# >epoch=4829, lrate=0.100, error=5.034
# >epoch=4830, lrate=0.100, error=5.034
# >epoch=4831, lrate=0.100, error=5.034
# >epoch=4832, lrate=0.100, error=5.034
# >epoch=4833, lrate=0.100, error=5.034
# >epoch=4834, lrate=0.100, error=5.034
# >epoch=4835, lrate=0.100, error=5.034
# >epoch=4836, lrate=0.100, error=5.034
# >epoch=4837, lrate=0.100, error=5.034
# >epoch=4838, lrate=0.100, error=5.034
# >epoch=4839, lrate=0.100, error=5.034
# >epoch=4840, lrate=0.100, error=5.034
# >epoch=4841, lrate=0.100, error=5.034
# >epoch=4842, lrate=0.100, error=5.034
# >epoch=4843, lrate=0.100, error=5.034
# >epoch=4844, lrate=0.100, error=5.034
# >epoch=4845, lrate=0.100, error=5.034
# >epoch=4846, lrate=0.100, error=5.034
# >epoch=4847, lrate=0.100, error=5.034
# >epoch=4848, lrate=0.100, error=5.034
# >epoch=4849, lrate=0.100, error=5.034
# >epoch=4850, lrate=0.100, error=5.034
# >epoch=4851, lrate=0.100, error=5.034
# >epoch=4852, lrate=0.100, error=5.034
# >epoch=4853, lrate=0.100, error=5.034
# >epoch=4854, lrate=0.100, error=5.034
# >epoch=4855, lrate=0.100, error=5.034
# >epoch=4856, lrate=0.100, error=5.034
# >epoch=4857, lrate=0.100, error=5.034
# >epoch=4858, lrate=0.100, error=5.034
# >epoch=4859, lrate=0.100, error=5.034
# >epoch=4860, lrate=0.100, error=5.034
# >epoch=4861, lrate=0.100, error=5.034
# >epoch=4862, lrate=0.100, error=5.034
# >epoch=4863, lrate=0.100, error=5.034
# >epoch=4864, lrate=0.100, error=5.034
# >epoch=4865, lrate=0.100, error=5.034
# >epoch=4866, lrate=0.100, error=5.034
# >epoch=4867, lrate=0.100, error=5.034
# >epoch=4868, lrate=0.100, error=5.034
# >epoch=4869, lrate=0.100, error=5.034
# >epoch=4870, lrate=0.100, error=5.034
# >epoch=4871, lrate=0.100, error=5.034
# >epoch=4872, lrate=0.100, error=5.034
# >epoch=4873, lrate=0.100, error=5.034
# >epoch=4874, lrate=0.100, error=5.034
# >epoch=4875, lrate=0.100, error=5.034
# >epoch=4876, lrate=0.100, error=5.034
# >epoch=4877, lrate=0.100, error=5.034
# >epoch=4878, lrate=0.100, error=5.034
# >epoch=4879, lrate=0.100, error=5.034
# >epoch=4880, lrate=0.100, error=5.034
# >epoch=4881, lrate=0.100, error=5.034
# >epoch=4882, lrate=0.100, error=5.034
# >epoch=4883, lrate=0.100, error=5.034
# >epoch=4884, lrate=0.100, error=5.034
# >epoch=4885, lrate=0.100, error=5.034
# >epoch=4886, lrate=0.100, error=5.034
# >epoch=4887, lrate=0.100, error=5.034
# >epoch=4888, lrate=0.100, error=5.034
# >epoch=4889, lrate=0.100, error=5.034
# >epoch=4890, lrate=0.100, error=5.034
# >epoch=4891, lrate=0.100, error=5.034
# >epoch=4892, lrate=0.100, error=5.034
# >epoch=4893, lrate=0.100, error=5.034
# >epoch=4894, lrate=0.100, error=5.034
# >epoch=4895, lrate=0.100, error=5.034
# >epoch=4896, lrate=0.100, error=5.034
# >epoch=4897, lrate=0.100, error=5.034
# >epoch=4898, lrate=0.100, error=5.034
# >epoch=4899, lrate=0.100, error=5.034
# >epoch=4900, lrate=0.100, error=5.034
# >epoch=4901, lrate=0.100, error=5.034
# >epoch=4902, lrate=0.100, error=5.034
# >epoch=4903, lrate=0.100, error=5.034
# >epoch=4904, lrate=0.100, error=5.034
# >epoch=4905, lrate=0.100, error=5.034
# >epoch=4906, lrate=0.100, error=5.034
# >epoch=4907, lrate=0.100, error=5.034
# >epoch=4908, lrate=0.100, error=5.034
# >epoch=4909, lrate=0.100, error=5.034
# >epoch=4910, lrate=0.100, error=5.034
# >epoch=4911, lrate=0.100, error=5.034
# >epoch=4912, lrate=0.100, error=5.034
# >epoch=4913, lrate=0.100, error=5.034
# >epoch=4914, lrate=0.100, error=5.034
# >epoch=4915, lrate=0.100, error=5.034
# >epoch=4916, lrate=0.100, error=5.034
# >epoch=4917, lrate=0.100, error=5.034
# >epoch=4918, lrate=0.100, error=5.034
# >epoch=4919, lrate=0.100, error=5.034
# >epoch=4920, lrate=0.100, error=5.034
# >epoch=4921, lrate=0.100, error=5.034
# >epoch=4922, lrate=0.100, error=5.034
# >epoch=4923, lrate=0.100, error=5.034
# >epoch=4924, lrate=0.100, error=5.034
# >epoch=4925, lrate=0.100, error=5.034
# >epoch=4926, lrate=0.100, error=5.034
# >epoch=4927, lrate=0.100, error=5.034
# >epoch=4928, lrate=0.100, error=5.034
# >epoch=4929, lrate=0.100, error=5.034
# >epoch=4930, lrate=0.100, error=5.034
# >epoch=4931, lrate=0.100, error=5.034
# >epoch=4932, lrate=0.100, error=5.034
# >epoch=4933, lrate=0.100, error=5.034
# >epoch=4934, lrate=0.100, error=5.034
# >epoch=4935, lrate=0.100, error=5.034
# >epoch=4936, lrate=0.100, error=5.034
# >epoch=4937, lrate=0.100, error=5.034
# >epoch=4938, lrate=0.100, error=5.034
# >epoch=4939, lrate=0.100, error=5.034
# >epoch=4940, lrate=0.100, error=5.034
# >epoch=4941, lrate=0.100, error=5.034
# >epoch=4942, lrate=0.100, error=5.034
# >epoch=4943, lrate=0.100, error=5.034
# >epoch=4944, lrate=0.100, error=5.034
# >epoch=4945, lrate=0.100, error=5.034
# >epoch=4946, lrate=0.100, error=5.034
# >epoch=4947, lrate=0.100, error=5.034
# >epoch=4948, lrate=0.100, error=5.034
# >epoch=4949, lrate=0.100, error=5.034
# >epoch=4950, lrate=0.100, error=5.034
# >epoch=4951, lrate=0.100, error=5.034
# >epoch=4952, lrate=0.100, error=5.034
# >epoch=4953, lrate=0.100, error=5.034
# >epoch=4954, lrate=0.100, error=5.034
# >epoch=4955, lrate=0.100, error=5.034
# >epoch=4956, lrate=0.100, error=5.034
# >epoch=4957, lrate=0.100, error=5.034
# >epoch=4958, lrate=0.100, error=5.034
# >epoch=4959, lrate=0.100, error=5.034
# >epoch=4960, lrate=0.100, error=5.034
# >epoch=4961, lrate=0.100, error=5.034
# >epoch=4962, lrate=0.100, error=5.034
# >epoch=4963, lrate=0.100, error=5.034
# >epoch=4964, lrate=0.100, error=5.034
# >epoch=4965, lrate=0.100, error=5.034
# >epoch=4966, lrate=0.100, error=5.034
# >epoch=4967, lrate=0.100, error=5.034
# >epoch=4968, lrate=0.100, error=5.034
# >epoch=4969, lrate=0.100, error=5.034
# >epoch=4970, lrate=0.100, error=5.034
# >epoch=4971, lrate=0.100, error=5.034
# >epoch=4972, lrate=0.100, error=5.034
# >epoch=4973, lrate=0.100, error=5.034
# >epoch=4974, lrate=0.100, error=5.034
# >epoch=4975, lrate=0.100, error=5.034
# >epoch=4976, lrate=0.100, error=5.034
# >epoch=4977, lrate=0.100, error=5.034
# >epoch=4978, lrate=0.100, error=5.034
# >epoch=4979, lrate=0.100, error=5.034
# >epoch=4980, lrate=0.100, error=5.034
# >epoch=4981, lrate=0.100, error=5.034
# >epoch=4982, lrate=0.100, error=5.034
# >epoch=4983, lrate=0.100, error=5.034
# >epoch=4984, lrate=0.100, error=5.034
# >epoch=4985, lrate=0.100, error=5.034
# >epoch=4986, lrate=0.100, error=5.034
# >epoch=4987, lrate=0.100, error=5.034
# >epoch=4988, lrate=0.100, error=5.034
# >epoch=4989, lrate=0.100, error=5.034
# >epoch=4990, lrate=0.100, error=5.034
# >epoch=4991, lrate=0.100, error=5.034
# >epoch=4992, lrate=0.100, error=5.034
# >epoch=4993, lrate=0.100, error=5.034
# >epoch=4994, lrate=0.100, error=5.034
# >epoch=4995, lrate=0.100, error=5.034
# >epoch=4996, lrate=0.100, error=5.034
# >epoch=4997, lrate=0.100, error=5.034
# >epoch=4998, lrate=0.100, error=5.034
# >epoch=4999, lrate=0.100, error=5.034

# %%
# after training the watermarked weights are as it is
for layer in network:
	print("after: ", layer)
# Out:
# after:  [{'weights': [0.03812149344356955, 0.02696345670343587, 0.02599648894976469], 'output': 0.6018462491296204, 'delta': -2.4002466453147895e-05}, {'weights': [0.1008, 0.0341064417983815, 0.02671267051101882], 'output': 0.7150216598119407, 'delta': -1.7156738342375747e-05}, {'weights': [0.03497040449457786, 0.019358628650952055, 0.022936389651715922], 'output': 0.5888569805696708, 'delta': -2.5018219206002447e-05}, {'weights': [0.035517232195041964, 0.021667482369683418, 0.01953393678825977], 'output': 0.5910082601194829, 'delta': -2.362414738136102e-05}, {'weights': [0.02929746978686172, 0.025015754172839008, 0.022800569023544506], 'output': 0.5830775792839367, 'delta': -2.3408129822324413e-05}, {'weights': [0.03910639107769908, 0.01856636716844865, 0.008532462616381221], 'output': 0.5923758280375931, 'delta': -2.382327144175214e-05}, {'weights': [0.01583508283832158, 0.0395559039899027, 0.02713400531226178], 'output': 0.5713749100636992, 'delta': -2.4627824241017852e-05}]
# after:  [{'weights': [0.205542108627677, 0.21977194988352425, 0.2362359918444892, 0.21313016447182279, 0.213117876578977, 0.22201984951890244, 0.22383522743923925, 0.21353491139677913], 'output': 0.758263443752582, 'delta': -0.00010071318474080548}, {'weights': [0.2362058627876703, 0.10052000000000001, 0.23718656708420377, 0.20748813170510805, 0.22260702516234893, 0.2206136248691779, 0.22590160846381063, 0.20537071254831937], 'output': 0.7448451350301871, 'delta': -0.0001045079456191053}, {'weights': [0.1379438551875348, 0.10319258596187209, 0.125379085738496, 0.1323489379134982, 0.12858081160870477, 0.13380672019970077, 0.14442966489640163, 0.13064378597846113], 'output': 0.6629123988198811, 'delta': -7.760588531877242e-05}, {'weights': [0.20810137569878864, 0.21978748621390573, 0.23369750052731467, 0.22386002297339372, 0.21504659153298303, 0.2260111068577529, 0.23067492280536853, 0.23659466883971145], 'output': 0.7649543590093147, 'delta': -9.95331706358681e-05}, {'weights': [0.22960215212492624, 0.2130334006044371, 0.2139163114458988, 0.21654196092831446, 0.19832830950552194, 0.20014397110158905, 0.19892211320807363, 0.21703016180400808], 'output': 0.7520166278525916, 'delta': -0.00010172657197351476}]
# after:  [{'weights': [-0.7760730244377294, -0.7670810761412488, -0.7746739140490815, -0.7750427110135312, -0.760792401007552, -0.7739322610033852], 'output': 0.026278127532251574, 'delta': 0.0001928659113032921}, {'weights': [-0.856492683167031, -0.8495570548998372, 0.09996000000000001, -0.8675483213084432, -0.8647336855840775, -0.86541062424825], 'output': 0.032439655417352845, 'delta': 0.00021336816805504055}, {'weights': [-0.7696052176527249, -0.7826002232795445, -0.7774045932959054, -0.7766091796334774, -0.7597855072971454, -0.7827844094913409], 'output': 0.025826483425593693, 'delta': 0.0002819653876619519}]
# after:  [{'weights': [-0.04344463452092637, -0.041171798582927785, -0.05943328748893939, -0.029928059145147227], 'output': 0.49486918534925284, 'delta': -0.1237042687778475}, {'weights': [0.04222773217648834, 0.03852201642071425, 0.0559037987780612, 0.030145130538829685], 'output': 0.5051328236261454, 'delta': 0.12370375638302208}]

# %%
test_network(network, [[2.7810836,2.550537003], [7.627531214,2.759262235]])
# Out:
# outputs: [0.49146169719256455, 0.5085374978181163]
# outputs: [0.49151067820590133, 0.5084910537553583]

# %% [markdown]
# get watermark

# %%
# selected weights from each layer to be watermarked
W= dict()
W[0]=[1,0] 
W[1]=[1,1]
W[2]=[1,2]

# update the weight located in W
for item in range(len(W)):
  layer = item
  mu = 0.1
  sigma = 0.001
  neuron_with_weight=W[item]
  value_of_selected_weight = network[layer][neuron_with_weight[0]]['weights'][neuron_with_weight[1]]
  print("weight of", layer, "neuron", neuron_with_weight[0],"weight index", neuron_with_weight[1], "->", value_of_selected_weight)
  watermark = ((value_of_selected_weight - mu)/ (2 * sigma)) + 0.5
  network[layer][neuron_with_weight[0]]['weights'][neuron_with_weight[1]] = value_of_selected_weight
  print("watermark ",item,":", round(watermark, 2))
# Out:
# weight of 0 neuron 1 weight index 0 -> 0.1008
# watermark  0 : 0.9
# weight of 1 neuron 1 weight index 1 -> 0.10052000000000001
# watermark  1 : 0.76
# weight of 2 neuron 1 weight index 2 -> 0.09996000000000001
# watermark  2 : 0.48

# %% [markdown]
# make perturbed model

# %%
# save the model to disk
import pickle
filename = 'finalized_model.sav'
pickle.dump(network, open(filename, 'wb'))

# %%
# perturbed models of the original 
loaded_model = pickle.load(open(filename, 'rb'))
for layer in loaded_model:
	print("perturbed model: ", layer)
# Out:
# perturbed model:  [{'weights': [0.03812149344356955, 0.02696345670343587, 0.02599648894976469], 'output': 0.5965639885884741, 'delta': -2.4002466453147895e-05}, {'weights': [0.1008, 0.0341064417983815, 0.02671267051101882], 'output': 0.708823395328842, 'delta': -1.7156738342375747e-05}, {'weights': [0.03497040449457786, 0.019358628650952055, 0.022936389651715922], 'output': 0.584940870307593, 'delta': -2.5018219206002447e-05}, {'weights': [0.035517232195041964, 0.021667482369683418, 0.01953393678825977], 'output': 0.586673109675671, 'delta': -2.362414738136102e-05}, {'weights': [0.02929746978686172, 0.025015754172839008, 0.022800569023544506], 'output': 0.5781766840879552, 'delta': -2.3408129822324413e-05}, {'weights': [0.03910639107769908, 0.01856636716844865, 0.008532462616381221], 'output': 0.5885676237728372, 'delta': -2.382327144175214e-05}, {'weights': [0.01583508283832158, 0.0395559039899027, 0.02713400531226178], 'output': 0.5639138573671285, 'delta': -2.4627824241017852e-05}]
# perturbed model:  [{'weights': [0.205542108627677, 0.21977194988352425, 0.2362359918444892, 0.21313016447182279, 0.213117876578977, 0.22201984951890244, 0.22383522743923925, 0.21353491139677913], 'output': 0.756810611576019, 'delta': -0.00010071318474080548}, {'weights': [0.2362058627876703, 0.10052000000000001, 0.23718656708420377, 0.20748813170510805, 0.22260702516234893, 0.2206136248691779, 0.22590160846381063, 0.20537071254831937], 'output': 0.7434432700719619, 'delta': -0.0001045079456191053}, {'weights': [0.1379438551875348, 0.10319258596187209, 0.125379085738496, 0.1323489379134982, 0.12858081160870477, 0.13380672019970077, 0.14442966489640163, 0.13064378597846113], 'output': 0.6618633422139191, 'delta': -7.760588531877242e-05}, {'weights': [0.20810137569878864, 0.21978748621390573, 0.23369750052731467, 0.22386002297339372, 0.21504659153298303, 0.2260111068577529, 0.23067492280536853, 0.23659466883971145], 'output': 0.7635065829060784, 'delta': -9.95331706358681e-05}, {'weights': [0.22960215212492624, 0.2130334006044371, 0.2139163114458988, 0.21654196092831446, 0.19832830950552194, 0.20014397110158905, 0.19892211320807363, 0.21703016180400808], 'output': 0.7506000904804021, 'delta': -0.00010172657197351476}]
# perturbed model:  [{'weights': [-0.7760730244377294, -0.7670810761412488, -0.7746739140490815, -0.7750427110135312, -0.760792401007552, -0.7739322610033852], 'output': 0.026414227374453536, 'delta': 0.0001928659113032921}, {'weights': [-0.856492683167031, -0.8495570548998372, 0.09996000000000001, -0.8675483213084432, -0.8647336855840775, -0.86541062424825], 'output': 0.03259371660536777, 'delta': 0.00021336816805504055}, {'weights': [-0.7696052176527249, -0.7826002232795445, -0.7774045932959054, -0.7766091796334774, -0.7597855072971454, -0.7827844094913409], 'output': 0.025961767827198987, 'delta': 0.0002819653876619519}]
# perturbed model:  [{'weights': [-0.04344463452092637, -0.041171798582927785, -0.05943328748893939, -0.029928059145147227], 'output': 0.49151067820590133, 'delta': -0.1237042687778475}, {'weights': [0.04222773217648834, 0.03852201642071425, 0.0559037987780612, 0.030145130538829685], 'output': 0.5084910537553583, 'delta': 0.12370375638302208}]

# %% [markdown]
# add noise in the watermark

# %%
# values are initialized according to main model with some noise added into watermark values
for item in range(len(W)):
  layer = item
  neuron_with_weight=W[item]
  value_of_selected_weight = loaded_model[layer][neuron_with_weight[0]]['weights'][neuron_with_weight[1]]
  print("before update layer", layer, "neuron", neuron_with_weight[0],"weight index", neuron_with_weight[1], "->", value_of_selected_weight)
  value_of_selected_weight = value_of_selected_weight + np.random.normal(0,0.01)
  loaded_model[layer][neuron_with_weight[0]]['weights'][neuron_with_weight[1]] = value_of_selected_weight
  print("after update layer ", layer, "neuron", neuron_with_weight[0],"weight index", neuron_with_weight[1], "->", loaded_model[layer][neuron_with_weight[0]]['weights'][neuron_with_weight[1]])
# result = loaded_model.score(X_test, Y_test)
# Out:
# before update layer 0 neuron 1 weight index 0 -> 0.1008
# after update layer  0 neuron 1 weight index 0 -> 0.08301736186626135
# before update layer 1 neuron 1 weight index 1 -> 0.10052000000000001
# after update layer  1 neuron 1 weight index 1 -> 0.09518078953876245
# before update layer 2 neuron 1 weight index 2 -> 0.09996000000000001
# after update layer  2 neuron 1 weight index 2 -> 0.10611728180864399

# %%
for layer in loaded_model:
	print(layer)
# Out:
# [{'weights': [0.03812149344356955, 0.02696345670343587, 0.02599648894976469], 'output': 0.5965639885884741, 'delta': -2.4002466453147895e-05}, {'weights': [0.08301736186626135, 0.0341064417983815, 0.02671267051101882], 'output': 0.708823395328842, 'delta': -1.7156738342375747e-05}, {'weights': [0.03497040449457786, 0.019358628650952055, 0.022936389651715922], 'output': 0.584940870307593, 'delta': -2.5018219206002447e-05}, {'weights': [0.035517232195041964, 0.021667482369683418, 0.01953393678825977], 'output': 0.586673109675671, 'delta': -2.362414738136102e-05}, {'weights': [0.02929746978686172, 0.025015754172839008, 0.022800569023544506], 'output': 0.5781766840879552, 'delta': -2.3408129822324413e-05}, {'weights': [0.03910639107769908, 0.01856636716844865, 0.008532462616381221], 'output': 0.5885676237728372, 'delta': -2.382327144175214e-05}, {'weights': [0.01583508283832158, 0.0395559039899027, 0.02713400531226178], 'output': 0.5639138573671285, 'delta': -2.4627824241017852e-05}]
# [{'weights': [0.205542108627677, 0.21977194988352425, 0.2362359918444892, 0.21313016447182279, 0.213117876578977, 0.22201984951890244, 0.22383522743923925, 0.21353491139677913], 'output': 0.756810611576019, 'delta': -0.00010071318474080548}, {'weights': [0.2362058627876703, 0.09518078953876245, 0.23718656708420377, 0.20748813170510805, 0.22260702516234893, 0.2206136248691779, 0.22590160846381063, 0.20537071254831937], 'output': 0.7434432700719619, 'delta': -0.0001045079456191053}, {'weights': [0.1379438551875348, 0.10319258596187209, 0.125379085738496, 0.1323489379134982, 0.12858081160870477, 0.13380672019970077, 0.14442966489640163, 0.13064378597846113], 'output': 0.6618633422139191, 'delta': -7.760588531877242e-05}, {'weights': [0.20810137569878864, 0.21978748621390573, 0.23369750052731467, 0.22386002297339372, 0.21504659153298303, 0.2260111068577529, 0.23067492280536853, 0.23659466883971145], 'output': 0.7635065829060784, 'delta': -9.95331706358681e-05}, {'weights': [0.22960215212492624, 0.2130334006044371, 0.2139163114458988, 0.21654196092831446, 0.19832830950552194, 0.20014397110158905, 0.19892211320807363, 0.21703016180400808], 'output': 0.7506000904804021, 'delta': -0.00010172657197351476}]
# [{'weights': [-0.7760730244377294, -0.7670810761412488, -0.7746739140490815, -0.7750427110135312, -0.760792401007552, -0.7739322610033852], 'output': 0.026414227374453536, 'delta': 0.0001928659113032921}, {'weights': [-0.856492683167031, -0.8495570548998372, 0.10611728180864399, -0.8675483213084432, -0.8647336855840775, -0.86541062424825], 'output': 0.03259371660536777, 'delta': 0.00021336816805504055}, {'weights': [-0.7696052176527249, -0.7826002232795445, -0.7774045932959054, -0.7766091796334774, -0.7597855072971454, -0.7827844094913409], 'output': 0.025961767827198987, 'delta': 0.0002819653876619519}]
# [{'weights': [-0.04344463452092637, -0.041171798582927785, -0.05943328748893939, -0.029928059145147227], 'output': 0.49151067820590133, 'delta': -0.1237042687778475}, {'weights': [0.04222773217648834, 0.03852201642071425, 0.0559037987780612, 0.030145130538829685], 'output': 0.5084910537553583, 'delta': 0.12370375638302208}]

# %% [markdown]
# get gradient from the perturbed model

# %%
# after adding noise extract gradients of all weights from perturbed models.
def backward_propagate_error_for_perturbed_models(model, expected):
  for i in reversed(range(len(model))):
    layer = model[i] # last to first
    errors = list() 
    if i != len(model)-1: # from 2nd last to first layer
      for j in range(len(layer)):
        error = 0.0
        for neuron in model[i + 1]: # 
          error += (neuron['weights'][j] * neuron['delta']) # total error for a neuron w.r.t connected neurons from back
        errors.append(error)
    else:   # 1st execute here to calculate loss (expected - predected) 
      for j in range(len(layer)): # last layer
        neuron = layer[j]
        errors.append(expected[j] - neuron['output']) # loss of output neurons
    for j in range(len(layer)):  # calculate gradient/ derivative(small portion from error w.r.t output of that neuron)
      neuron = layer[j]
      neuron['delta'] = errors[j] * derivative(neuron['output']) # store the derivative
  return model

perturbed_network = backward_propagate_error_for_perturbed_models(loaded_model, expected_output)

# %%
print("gradiens and weights of the perturbed model")
for layers in perturbed_network:
  print(layers)
# Out:
# gradiens and weights of the perturbed model
# [{'weights': [0.03812149344356955, 0.02696345670343587, 0.02599648894976469], 'output': 0.5965639885884741, 'delta': -3.2891296325419064e-05}, {'weights': [0.08301736186626135, 0.0341064417983815, 0.02671267051101882], 'output': 0.708823395328842, 'delta': -2.3567696980334914e-05}, {'weights': [0.03497040449457786, 0.019358628650952055, 0.022936389651715922], 'output': 0.584940870307593, 'delta': -3.424854565216472e-05}, {'weights': [0.035517232195041964, 0.021667482369683418, 0.01953393678825977], 'output': 0.586673109675671, 'delta': -3.23380399275585e-05}, {'weights': [0.02929746978686172, 0.025015754172839008, 0.022800569023544506], 'output': 0.5781766840879552, 'delta': -3.2045492036999885e-05}, {'weights': [0.03910639107769908, 0.01856636716844865, 0.008532462616381221], 'output': 0.5885676237728372, 'delta': -3.259904117026103e-05}, {'weights': [0.01583508283832158, 0.0395559039899027, 0.02713400531226178], 'output': 0.5639138573671285, 'delta': -3.373371011954763e-05}]
# [{'weights': [0.205542108627677, 0.21977194988352425, 0.2362359918444892, 0.21313016447182279, 0.213117876578977, 0.22201984951890244, 0.22383522743923925, 0.21353491139677913], 'output': 0.756810611576019, 'delta': -0.00013806613142422968}, {'weights': [0.2362058627876703, 0.09518078953876245, 0.23718656708420377, 0.20748813170510805, 0.22260702516234893, 0.2206136248691779, 0.22590160846381063, 0.20537071254831937], 'output': 0.7434432700719619, 'delta': -0.000143098031665318}, {'weights': [0.1379438551875348, 0.10319258596187209, 0.125379085738496, 0.1323489379134982, 0.12858081160870477, 0.13380672019970077, 0.14442966489640163, 0.13064378597846113], 'output': 0.6618633422139191, 'delta': -0.00010192662552597898}, {'weights': [0.20810137569878864, 0.21978748621390573, 0.23369750052731467, 0.22386002297339372, 0.21504659153298303, 0.2260111068577529, 0.23067492280536853, 0.23659466883971145], 'output': 0.7635065829060784, 'delta': -0.00013647151347092576}, {'weights': [0.22960215212492624, 0.2130334006044371, 0.2139163114458988, 0.21654196092831446, 0.19832830950552194, 0.20014397110158905, 0.19892211320807363, 0.21703016180400808], 'output': 0.7506000904804021, 'delta': -0.0001394735187139011}]
# [{'weights': [-0.7760730244377294, -0.7670810761412488, -0.7746739140490815, -0.7750427110135312, -0.760792401007552, -0.7739322610033852], 'output': 0.026414227374453536, 'delta': 0.0002706449124925359}, {'weights': [-0.856492683167031, -0.8495570548998372, 0.10611728180864399, -0.8675483213084432, -0.8647336855840775, -0.86541062424825], 'output': 0.03259371660536777, 'delta': 0.0003086841952383348}, {'weights': [-0.7696052176527249, -0.7826002232795445, -0.7774045932959054, -0.7766091796334774, -0.7597855072971454, -0.7827844094913409], 'output': 0.025961767827198987, 'delta': 0.0003582830204986195}]
# [{'weights': [-0.04344463452092637, -0.041171798582927785, -0.05943328748893939, -0.029928059145147227], 'output': 0.49151067820590133, 'delta': -0.12284224707261872}, {'weights': [0.04222773217648834, 0.03852201642071425, 0.0559037987780612, 0.030145130538829685], 'output': 0.5084910537553583, 'delta': 0.12284179975216389}]

# %% [markdown]
# update the non watermarked weight

# %%
# Update network weights with error
def update_weights_2(perturbed_network, network, row, l_rate, W):
  for i in range(len(network)):
    inputs = row[:-1]
    if i != 0:
      inputs = [neuron['output'] for neuron in network[i - 1]]  # from 2nd layer output of 1st= input of 2nd
    for neuron in range(len(network[i])):  # neuron in a layer
      # print(network[i][neuron])   
      for j in range(len(inputs)):
        try:
          layer_number = W[i][0]
        except:
          layer_number = -10
        if neuron == layer_number:
          try:
            weight_number = W[i][1]
          except:
            weight_number = -10
          if j == weight_number:
            # network[i][neuron]['weights'][j] += 0 * l_rate * network[i][neuron]['delta'] * inputs[j]
            network[i][neuron]['weights'][j] += 0 * l_rate * network[i][neuron]['delta'] - 0.0001 * perturbed_network[i][neuron]['delta']
            # print(network[i][neuron]['weights'][j])  
          else:
            # network[i][neuron]['weights'][j] += l_rate * network[i][neuron]['delta'] * inputs[j] 
            network[i][neuron]['weights'][j] += l_rate * network[i][neuron]['delta'] - 0.0001 * perturbed_network[i][neuron]['delta']
        else:
          # print(network[i][neuron])
          # network[i][neuron]['weights'][j] += l_rate * network[i][neuron]['delta'] * inputs[j]
          network[i][neuron]['weights'][j] += l_rate * network[i][neuron]['delta'] - 0.0001 * perturbed_network[i][neuron]['delta']
      # for j in range(len(inputs)):
      #   print(network[i][neuron]['weights'][j])
      #   neuron['weights'][j] += l_rate * neuron['delta'] * inputs[j]
      network[i][neuron]['weights'][-1] += l_rate * network[i][neuron]['delta'] - - 0.0001 * perturbed_network[i][neuron]['delta']

# %%
update_weights_2(perturbed_network, network, row, 0.1, W)

# %%
for layers in network:
  print(layers)
# Out:
# [{'weights': [0.03811909648605387, 0.026961059745920186, 0.025994085413989742], 'output': 0.5965639885884741, 'delta': -2.4002466453147895e-05}, {'weights': [0.1008000023567697, 0.03410472848131696, 0.02671095248041488], 'output': 0.708823395328842, 'delta': -1.7156738342375747e-05}, {'weights': [0.034967906097511825, 0.01935613025388602, 0.022933884404940756], 'output': 0.584940870307593, 'delta': -2.5018219206002447e-05}, {'weights': [0.03551487301410782, 0.021665123188749275, 0.01953157113971764], 'output': 0.586673109675671, 'delta': -2.362414738136102e-05}, {'weights': [0.029295132178428693, 0.02501341656440598, 0.02279822500601307], 'output': 0.5781766840879552, 'delta': -2.3408129822324413e-05}, {'weights': [0.03910401201045902, 0.018563988101208594, 0.008530077029332929], 'output': 0.5885676237728372, 'delta': -2.382327144175214e-05}, {'weights': [0.01583262342926849, 0.039553444580849605, 0.02713153915646667], 'output': 0.5639138573671285, 'delta': -2.4627824241017852e-05}]
# [{'weights': [0.20553205111581604, 0.2197618923716633, 0.23622593433262826, 0.21312010695996184, 0.21310781906711604, 0.2220097920070415, 0.2238251699273783, 0.21352482627169192], 'output': 0.756810611576019, 'delta': -0.00010071318474080548}, {'weights': [0.23619542630291157, 0.10052001430980317, 0.23717613059944503, 0.2074776952203493, 0.2225965886775902, 0.22060318838441917, 0.2258911719790519, 0.20536024744395429], 'output': 0.7434432700719619, 'delta': -0.0001045079456191053}, {'weights': [0.13793610479166546, 0.10318483556600276, 0.12537133534262665, 0.13234118751762886, 0.12857306121283543, 0.13379896980383144, 0.1444219145005323, 0.1306360151972667], 'output': 0.6618633422139191, 'delta': -7.760588531877242e-05}, {'weights': [0.2080914360288764, 0.21977754654399348, 0.23368756085740242, 0.22385008330348147, 0.21503665186307078, 0.22600116718784066, 0.23066498313545628, 0.23658470187549652], 'output': 0.7635065829060784, 'delta': -9.95331706358681e-05}, {'weights': [0.22959199341508077, 0.21302324189459163, 0.21390615273605332, 0.216531802218469, 0.19831815079567647, 0.20013381239174358, 0.19891195449822816, 0.21701997519945887], 'output': 0.7506000904804021, 'delta': -0.00010172657197351476}]
# [{'weights': [-0.7760537649110903, -0.7670618166146097, -0.7746546545224424, -0.7750234514868921, -0.7607731414809129, -0.7739129473477636], 'output': 0.026414227374453536, 'delta': 0.0001928659113032921}, {'weights': [-0.856471377218645, -0.8495357489514512, 0.09995996913158048, -0.8675270153600572, -0.8647123796356915, -0.865389256563025], 'output': 0.03259371660536777, 'delta': 0.00021336816805504055}, {'weights': [-0.7695770569422608, -0.7825720625690803, -0.7773764325854412, -0.7765810189230132, -0.7597573465866813, -0.7827561771242726], 'output': 0.025961767827198987, 'delta': 0.0002819653876619519}]
# [{'weights': [-0.05580277717400386, -0.053529941236005275, -0.07179143014201689, -0.04231077024763924], 'output': 0.49151067820590133, 'delta': -0.1237042687778475}, {'weights': [0.05458582363481533, 0.050880107879041236, 0.06826189023638819, 0.04252779035710711], 'output': 0.5084910537553583, 'delta': 0.12370375638302208}]

# %%
for layers in perturbed_network:
  print(layers)
# Out:
# [{'weights': [0.03812149344356955, 0.02696345670343587, 0.02599648894976469], 'output': 0.5965639885884741, 'delta': -3.2891296325419064e-05}, {'weights': [0.08301736186626135, 0.0341064417983815, 0.02671267051101882], 'output': 0.708823395328842, 'delta': -2.3567696980334914e-05}, {'weights': [0.03497040449457786, 0.019358628650952055, 0.022936389651715922], 'output': 0.584940870307593, 'delta': -3.424854565216472e-05}, {'weights': [0.035517232195041964, 0.021667482369683418, 0.01953393678825977], 'output': 0.586673109675671, 'delta': -3.23380399275585e-05}, {'weights': [0.02929746978686172, 0.025015754172839008, 0.022800569023544506], 'output': 0.5781766840879552, 'delta': -3.2045492036999885e-05}, {'weights': [0.03910639107769908, 0.01856636716844865, 0.008532462616381221], 'output': 0.5885676237728372, 'delta': -3.259904117026103e-05}, {'weights': [0.01583508283832158, 0.0395559039899027, 0.02713400531226178], 'output': 0.5639138573671285, 'delta': -3.373371011954763e-05}]
# [{'weights': [0.205542108627677, 0.21977194988352425, 0.2362359918444892, 0.21313016447182279, 0.213117876578977, 0.22201984951890244, 0.22383522743923925, 0.21353491139677913], 'output': 0.756810611576019, 'delta': -0.00013806613142422968}, {'weights': [0.2362058627876703, 0.09518078953876245, 0.23718656708420377, 0.20748813170510805, 0.22260702516234893, 0.2206136248691779, 0.22590160846381063, 0.20537071254831937], 'output': 0.7434432700719619, 'delta': -0.000143098031665318}, {'weights': [0.1379438551875348, 0.10319258596187209, 0.125379085738496, 0.1323489379134982, 0.12858081160870477, 0.13380672019970077, 0.14442966489640163, 0.13064378597846113], 'output': 0.6618633422139191, 'delta': -0.00010192662552597898}, {'weights': [0.20810137569878864, 0.21978748621390573, 0.23369750052731467, 0.22386002297339372, 0.21504659153298303, 0.2260111068577529, 0.23067492280536853, 0.23659466883971145], 'output': 0.7635065829060784, 'delta': -0.00013647151347092576}, {'weights': [0.22960215212492624, 0.2130334006044371, 0.2139163114458988, 0.21654196092831446, 0.19832830950552194, 0.20014397110158905, 0.19892211320807363, 0.21703016180400808], 'output': 0.7506000904804021, 'delta': -0.0001394735187139011}]
# [{'weights': [-0.7760730244377294, -0.7670810761412488, -0.7746739140490815, -0.7750427110135312, -0.760792401007552, -0.7739322610033852], 'output': 0.026414227374453536, 'delta': 0.0002706449124925359}, {'weights': [-0.856492683167031, -0.8495570548998372, 0.10611728180864399, -0.8675483213084432, -0.8647336855840775, -0.86541062424825], 'output': 0.03259371660536777, 'delta': 0.0003086841952383348}, {'weights': [-0.7696052176527249, -0.7826002232795445, -0.7774045932959054, -0.7766091796334774, -0.7597855072971454, -0.7827844094913409], 'output': 0.025961767827198987, 'delta': 0.0003582830204986195}]
# [{'weights': [-0.04344463452092637, -0.041171798582927785, -0.05943328748893939, -0.029928059145147227], 'output': 0.49151067820590133, 'delta': -0.12284224707261872}, {'weights': [0.04222773217648834, 0.03852201642071425, 0.0559037987780612, 0.030145130538829685], 'output': 0.5084910537553583, 'delta': 0.12284179975216389}]

# %% [markdown]
# get the watermark

# %%
# get watermark

# selected weights from each layer to be watermarked
W= dict()
W[0]=[1,0] 
W[1]=[1,1]
W[2]=[1,2]

# update the weight located in W
for item in range(len(W)):
  layer = item
  mu = 0.1
  sigma = 0.001
  neuron_with_weight=W[item]
  value_of_selected_weight = network[layer][neuron_with_weight[0]]['weights'][neuron_with_weight[1]]
  print("weight of", layer, "neuron", neuron_with_weight[0],"weight index", neuron_with_weight[1], "->", value_of_selected_weight)
  watermark = ((value_of_selected_weight - mu)/ (2 * sigma)) + 0.5
  network[layer][neuron_with_weight[0]]['weights'][neuron_with_weight[1]] = value_of_selected_weight
  print("watermark ",item,":", round(watermark, 2))
# Out:
# weight of 0 neuron 1 weight index 0 -> 0.1008000023567697
# watermark  0 : 0.9
# weight of 1 neuron 1 weight index 1 -> 0.10052001430980317
# watermark  1 : 0.76
# weight of 2 neuron 1 weight index 2 -> 0.09995996913158048
# watermark  2 : 0.48

# %%
test_network(network, [[2.7810836,2.550537003], [7.627531214,2.759262235]])
# Out:
# outputs: [0.488092040940623, 0.5119071327655171]
# outputs: [0.48815370656275653, 0.511848003541458]
