# %% [markdown]
# <a href="https://colab.research.google.com/github/sumankmaiti/All-in-one/blob/main/DnCNN_tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
! git clone https://github.com/wbhu/DnCNN-tensorflow
# Out:
# Cloning into 'DnCNN-tensorflow'...
# remote: Enumerating objects: 1619, done.
# ^C

# %%
# %cd /content/drive/MyDrive/DnCNN-tensorflow
# Out:
# /content/drive/MyDrive/DnCNN-tensorflow

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
# read image
ORIGINAL = '/content/drive/MyDrive/Reverse_Engineering_GMs-main/test/PROG_GAN/prog_gan_100.jpg' 
img = cv2.imread(ORIGINAL)
# x = image.img_to_array(img) # 224, 224, 3
# x = np.expand_dims(img, axis=0) # 1, 224, 224, 3
# x = preprocess_input(x) # preprocessing the input for vgg16 model
img = img.astype('float32')/255.0
img
# img = np.clip(img, 0, 1)
# cv2_imshow(img*255.0)
# img.shape
# cv2.imwrite('/content/drive/MyDrive/DnCNN-tensorflow/data/test/original/00001.png', img*255.0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-25fe24174ce2> in <module>()
#       5 # x = np.expand_dims(img, axis=0) # 1, 224, 224, 3
#       6 # x = preprocess_input(x) # preprocessing the input for vgg16 model
# ----> 7 img = img.astype('float32')/255.0
#       8 img
#       9 # img = np.clip(img, 0, 1)
#
# AttributeError: 'NoneType' object has no attribute 'astype'

# %%
#define noise
noise_factor = 0.5
noise = np.random.normal(loc=0.0, scale=1.0, size=img.shape) 
noise
# noise_test = np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

# %%
# show noise
plt.imshow(noise, cmap="gray")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# apply noise on the original image
noisy_img = img + noise_factor * noise
noisy_img
# show the noisy image
# cv2_imshow(noisy_img*255.0)
# cv2.imwrite('/content/drive/MyDrive/DnCNN-tensorflow/data/test/noisy/00001.png', noisy_img*255.0)
# Out:
# array([[[ 7.12714474e-01,  1.28824681e+00,  1.86167416e-01],
#         [ 1.26984258e-01,  7.21966825e-01,  1.34065021e+00],
#         [ 1.00270164e+00,  3.17747165e-01,  5.04584573e-01],
#         ...,
#         [-2.10265668e-01,  1.37213775e+00,  7.45099148e-01],
#         [-1.35669448e-01,  5.62004590e-01,  8.21344795e-01],
#         [ 2.99075124e-01,  7.28934031e-02,  4.72696483e-01]],
#
#        [[-2.73179642e-02,  1.62827322e+00,  6.04960363e-01],
#         [ 8.16881498e-01,  8.88017513e-01, -3.83965084e-01],
#         [ 7.93589708e-01, -1.14952505e-03, -4.82141909e-01],
#         ...,
#         [-1.76257963e-01, -2.86685580e-01,  3.52957104e-01],
#         [ 1.03713886e+00, -4.63289863e-01,  9.96932870e-01],
#         [ 1.37982768e+00, -1.59048610e-01, -5.04178388e-01]],
#
#        [[ 9.12275354e-01,  9.18341499e-01,  6.27034531e-01],
#         [ 4.20526405e-01,  7.25475314e-01, -7.68046815e-01],
#         [ 1.01496403e+00,  9.50212912e-01,  4.47056753e-01],
#         ...,
# ...

# %%
# !python3 main.py
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:101: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2021-10-12 04:25:32.988858: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-10-12 04:25:32.988914: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (9ba3a5492453): /proc/driver/nvidia/version does not exist
# GPU
#
# /usr/local/lib/python3.7/dist-packages/keras/legacy_tf_layers/convolutional.py:536: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
#   warnings.warn('`tf.layers.conv2d` is deprecated and '
# ...

# %%
! python3 main.py --phase test
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:101: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2021-10-12 16:59:24.170056: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-10-12 16:59:24.170111: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ae2921a794e2): /proc/driver/nvidia/version does not exist
# GPU
#
# /usr/local/lib/python3.7/dist-packages/keras/legacy_tf_layers/convolutional.py:536: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
#   warnings.warn('`tf.layers.conv2d` is deprecated and '
# ...

# %%
from glob import glob

filepaths = glob('./data/train/original/*.png') 
ind = range(len(filepaths))
ind
# Out:
# range(0, 400)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# read image
ORIGINAL = '/content/drive/MyDrive/Reverse_Engineering_GMs-main/test/PROG_GAN/prog_gan_100.jpg' 
img = mpimg.imread(ORIGINAL)
# x = image.img_to_array(img) # 224, 224, 3
# x = np.expand_dims(x, axis=0) # 1, 224, 224, 3
# x = preprocess_input(x) # preprocessing the input for vgg16 model
img = img/255.0
plt.imshow(img)
img.shape
# Out:
# (160, 160, 3)

# %%
import cv2
a=cv2.imread('/content/drive/MyDrive/Reverse_Engineering_GMs-main/test/PROG_GAN/prog_gan_100.jpg' )
a[0][53][1]
# Out:
# 71

# %%
a=a.reshape(3,160,160)
a[0][1][0]
# Out:
# 71

# %%
img1=img.reshape(3,160,160)
img1
# Out:
# tensor([[[0.7137, 0.6627, 0.6392,  ..., 0.2784, 0.2078, 0.4627],
#          [0.2784, 0.2078, 0.4941,  ..., 0.1333, 0.2431, 0.1765],
#          [0.1373, 0.2039, 0.1373,  ..., 0.3059, 0.2353, 0.1882],
#          ...,
#          [0.6706, 0.5608, 0.8902,  ..., 0.5882, 0.9490, 0.6980],
#          [0.5882, 0.9529, 0.7020,  ..., 0.8000, 0.6314, 0.4941],
#          [0.4824, 0.3608, 0.2824,  ..., 0.6314, 0.5412, 0.8314]],
#
#         [[0.6353, 0.5294, 0.8392,  ..., 0.5765, 0.9451, 0.6902],
#          [0.5725, 0.9451, 0.6902,  ..., 0.8196, 0.6431, 0.5137],
#          [0.4745, 0.3451, 0.2706,  ..., 0.5608, 0.4745, 0.7569],
#          ...,
#          [0.5490, 0.8588, 0.6157,  ..., 0.9686, 0.9176, 0.9529],
#          [0.3412, 0.3373, 0.3569,  ..., 0.7137, 0.6078, 0.9333],
#          [0.7098, 0.6039, 0.9294,  ..., 0.5490, 0.8667, 0.6235]],
#
#         [[0.5255, 0.8392, 0.5961,  ..., 0.9686, 0.9216, 0.9373],
#          [0.0235, 0.0275, 0.0471,  ..., 0.7098, 0.6039, 0.9255],
# ...

# %%
model=DnCNN()
#model_params = list(model.parameters())    
#optimizer = torch.optim.Adam(model_params, lr=0.0001)

# state1 = torch.load('/content/drive/MyDrive/Reverse_Engineering_GMs-main/pre_trained_models/image_attribution/celeba/0_model_27_384000.pickle', map_location=torch.device('cpu'))
# optimizer.load_state_dict(state1['optimizer_1'])
# model.load_state_dict(state1['state_dict_cnn'])

model.eval()
# Out:
# DnCNN(
#   (layers): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (2): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %%
img = img.reshape(1, 160, 160,3)
#img = np.expand_dims(img, axis=0)

# %%
x = residual.numpy()
x=x.reshape(160,160,3)
print(x.shape)

y=x[:,:,0:1]
y.shape
plt.imshow(y.reshape(160,160))
# Out:
# (160, 160, 3)

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models

model = models.Sequential()
model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=(160, 160, 3), padding="same"))

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
img = np.expand_dims(img, axis=0)
img.shape
# Out:
# (1, 160, 160, 3)

# %%
model.evaluate(img)

# %%
history = model.fit(train_images, train_labels, epochs=10, 
                    validation_data=(test_images, test_labels))
